# %% [markdown]
# # C-More

# %% [markdown]
# ### Normalize keyword extraction data

# %%
import pymongo

# %%
client = pymongo.MongoClient('mongodb://localhost:27017/')

# %%
db = client['rep_analysis_main']

# %%
db.list_collection_names()
# Out:
# ['sentiment_monthly_main',
#  'data_test',
#  'emotions_weekly_main',
#  'kw_freq_weight_monthly_test',
#  'kw_freq_weight_test',
#  'kw_freq_weight_annually_test',
#  'client_info',
#  'sentiment_monthly_test',
#  'kw_daily_main',
#  'kw_freq_weight_daily_test',
#  'emotions_test',
#  'sentiment_annually_test',
#  'emotions_daily_main',
#  'sentiment_weekly_test',
#  'sentiment_weekly_main',
#  'data_twitter',
#  'emotions_yearly_main',
#  'sentiment_test',
#  'emotions_monthly_main',
#  'kw_yearly_main',
#  'sentiment_daily_test',
#  'sentiment_daily_main',
#  'kw_freq_weight_weekly_test',
#  'kw_weekly_main',
#  'sentiment_yearly_main',
#  'kw_monthly_main']

# %% [markdown]
# #### 1. Perform keyword extraction on a daily basis

# %% [markdown]
# We will start by running our kw_extraction.py script directly in order to have the **keyword extraction results normalized** for one day.

# %%
# db['kw_freq_weight_test_norm'].drop()

# %%
db.list_collection_names()
# Out:
# ['sentiment_monthly_main',
#  'data_test',
#  'emotions_weekly_main',
#  'kw_freq_weight_monthly_test',
#  'kw_freq_weight_test',
#  'kw_freq_weight_annually_test',
#  'client_info',
#  'sentiment_monthly_test',
#  'kw_daily_main',
#  'kw_freq_weight_daily_test',
#  'emotions_test',
#  'sentiment_annually_test',
#  'emotions_daily_main',
#  'sentiment_weekly_test',
#  'sentiment_weekly_main',
#  'data_twitter',
#  'emotions_yearly_main',
#  'sentiment_test',
#  'emotions_monthly_main',
#  'kw_yearly_main',
#  'kw_freq_weight_test_norm',
#  'sentiment_daily_test',
#  'sentiment_daily_main',
#  'kw_freq_weight_weekly_test',
#  'kw_weekly_main',
#  'sentiment_yearly_main',
#  'kw_monthly_main']

# %%
kw_norm = db['kw_freq_weight_test_norm']

# %%
for doc in kw_norm.find():
    print(doc)
# Out:
# {'_id': ObjectId('638e144b012d50bbe86ba659'), 'kw_weights': {'burger': 100, 'burger king': 69, 'fuck burger king': 65, 'fries': 57, 'donut lemon burger': 53, 'mcdonald’s&gt;&gt;&gt;burger king': 48, 'french fries': 38, 'curly fries': 32, 'charge burger': 24, 'warren burger': 21, 'chili cheese burger': 21, 'flavor fries': 20, 'dairy queen merger': 19, 'skanky burger': 17, 'fast food restaurants': 17, 'crazy day': 17, 'wet naps': 16, 'local street food': 15, 'burger king bruh': 15, 'sad girl era': 14, 'money': 14, 'smn burger': 14, 'burger ya kfc ke buns': 13, 'inappropriate office conduct': 13, 'burger ka sakin': 13, 'south william street burger joint': 13, 'american burger cheese': 13, 'super delicious burger': 13, 'water level': 12, 'big otsu': 12, 'burger king staff': 12, 'burger joint': 11, 'amp': 10, 'cheese burger': 10, 'big ass burger': 10, 'nothin burger': 10, 'big guy': 9, 'angel': 9, 'wrong': 9, 'cold burger': 9, 'people': 9, 'late night': 9, 'burgers': 8, 'best burger joint
# ...

# %%
for doc in kw_norm.find():
    print(doc['extracted_at'])
# Out:
# 2022-09-29

# %%
kw_norm.count_documents({})
# Out:
# 1

# %% [markdown]
# We have extracted the most relevant keywords for our first 100 tweets (2022-09-29), and the results are now normalized (weight values range from 0 to 1).
#
# We will now run the script again, changing the extraction date for the following days.

# %%
kw_norm.count_documents({})
# Out:
# 21

# %% [markdown]
# After running the script for all the available days, we get the results for all our tweets.

# %%
for doc in kw_norm.find():
    print(doc)
# Out:
# {'_id': ObjectId('638e144b012d50bbe86ba659'), 'kw_weights': {'burger': 100, 'burger king': 69, 'fuck burger king': 65, 'fries': 57, 'donut lemon burger': 53, 'mcdonald’s&gt;&gt;&gt;burger king': 48, 'french fries': 38, 'curly fries': 32, 'charge burger': 24, 'warren burger': 21, 'chili cheese burger': 21, 'flavor fries': 20, 'dairy queen merger': 19, 'skanky burger': 17, 'fast food restaurants': 17, 'crazy day': 17, 'wet naps': 16, 'local street food': 15, 'burger king bruh': 15, 'sad girl era': 14, 'money': 14, 'smn burger': 14, 'burger ya kfc ke buns': 13, 'inappropriate office conduct': 13, 'burger ka sakin': 13, 'south william street burger joint': 13, 'american burger cheese': 13, 'super delicious burger': 13, 'water level': 12, 'big otsu': 12, 'burger king staff': 12, 'burger joint': 11, 'amp': 10, 'cheese burger': 10, 'big ass burger': 10, 'nothin burger': 10, 'big guy': 9, 'angel': 9, 'wrong': 9, 'cold burger': 9, 'people': 9, 'late night': 9, 'burgers': 8, 'best burger joint
# ...

# %% [markdown]
# #### 2. Aggregate keyword extraction results per day

# %% [markdown]
# We will use the kw_norm collection as our source of data.
#
# After running the kw_extraction.py script for the daily aggregation ("2022-09-29"), we get:

# %%
db.list_collection_names()
# Out:
# ['sentiment_monthly_main',
#  'data_test',
#  'emotions_weekly_main',
#  'kw_freq_weight_monthly_test',
#  'kw_freq_weight_test',
#  'kw_freq_weight_annually_test',
#  'client_info',
#  'sentiment_monthly_test',
#  'kw_daily_main',
#  'kw_freq_weight_daily_test',
#  'emotions_test',
#  'sentiment_annually_test',
#  'emotions_daily_main',
#  'sentiment_weekly_test',
#  'sentiment_weekly_main',
#  'data_twitter',
#  'kw_freq_weight_test_norm',
#  'emotions_yearly_main',
#  'sentiment_test',
#  'emotions_monthly_main',
#  'kw_yearly_main',
#  'sentiment_daily_test',
#  'kw_daily_norm',
#  'sentiment_daily_main',
#  'kw_freq_weight_weekly_test',
#  'kw_weekly_main',
#  'sentiment_yearly_main',
#  'kw_monthly_main']

# %% [markdown]
# We have a new collection, **kw_daily_norm**.

# %%
kw_daily = db['kw_daily_norm']

# %%
for doc in kw_daily.find():
    print(doc)
# Out:
# {'_id': ObjectId('638e15ac0ee480ee030792ca'), 'extracted_at': '2022-09-29', 'year': '2022', 'month': '09', 'week_of_year': '39', 'kw_weights': {'burger': 100, 'burger king': 69, 'fuck burger king': 65, 'fries': 57, 'donut lemon burger': 53, 'mcdonald’s&gt;&gt;&gt;burger king': 48, 'french fries': 38, 'curly fries': 32, 'charge burger': 24, 'warren burger': 21, 'chili cheese burger': 21, 'flavor fries': 20, 'dairy queen merger': 19, 'skanky burger': 17, 'fast food restaurants': 17, 'crazy day': 17, 'wet naps': 16, 'local street food': 15, 'burger king bruh': 15, 'sad girl era': 14, 'money': 14, 'smn burger': 14, 'burger ya kfc ke buns': 13, 'inappropriate office conduct': 13, 'burger ka sakin': 13, 'south william street burger joint': 13, 'american burger cheese': 13, 'super delicious burger': 13, 'water level': 12, 'big otsu': 12, 'burger king staff': 12, 'burger joint': 11, 'amp': 10, 'cheese burger': 10, 'big ass burger': 10, 'nothin burger': 10, 'big guy': 9, 'angel': 9, 'wrong': 
# ...

# %%
kw_daily.count_documents({})
# Out:
# 1

# %% [markdown]
# We can now run the script for all the days we have available.

# %%
for doc in kw_daily.find():
    print(doc)
# Out:
# {'_id': ObjectId('638e15ac0ee480ee030792ca'), 'extracted_at': '2022-09-29', 'year': '2022', 'month': '09', 'week_of_year': '39', 'kw_weights': {'burger': 100, 'burger king': 69, 'fuck burger king': 65, 'fries': 57, 'donut lemon burger': 53, 'mcdonald’s&gt;&gt;&gt;burger king': 48, 'french fries': 38, 'curly fries': 32, 'charge burger': 24, 'warren burger': 21, 'chili cheese burger': 21, 'flavor fries': 20, 'dairy queen merger': 19, 'skanky burger': 17, 'fast food restaurants': 17, 'crazy day': 17, 'wet naps': 16, 'local street food': 15, 'burger king bruh': 15, 'sad girl era': 14, 'money': 14, 'smn burger': 14, 'burger ya kfc ke buns': 13, 'inappropriate office conduct': 13, 'burger ka sakin': 13, 'south william street burger joint': 13, 'american burger cheese': 13, 'super delicious burger': 13, 'water level': 12, 'big otsu': 12, 'burger king staff': 12, 'burger joint': 11, 'amp': 10, 'cheese burger': 10, 'big ass burger': 10, 'nothin burger': 10, 'big guy': 9, 'angel': 9, 'wrong': 
# ...

# %%
kw_daily.count_documents({})
# Out:
# 21

# %% [markdown]
# #### 3. Aggregate keyword extraction results per week

# %% [markdown]
# After running the kw_extraction.py script for the weekly aggregation ("39"), we get:

# %%
db.list_collection_names()
# Out:
# ['sentiment_monthly_main',
#  'data_test',
#  'emotions_weekly_main',
#  'kw_freq_weight_monthly_test',
#  'kw_freq_weight_test',
#  'kw_freq_weight_annually_test',
#  'client_info',
#  'sentiment_monthly_test',
#  'kw_daily_main',
#  'kw_freq_weight_daily_test',
#  'emotions_test',
#  'sentiment_annually_test',
#  'emotions_daily_main',
#  'sentiment_weekly_test',
#  'sentiment_weekly_main',
#  'data_twitter',
#  'kw_freq_weight_test_norm',
#  'emotions_yearly_main',
#  'sentiment_test',
#  'emotions_monthly_main',
#  'kw_yearly_main',
#  'sentiment_daily_test',
#  'kw_daily_norm',
#  'sentiment_daily_main',
#  'kw_weekly_norm',
#  'kw_freq_weight_weekly_test',
#  'kw_weekly_main',
#  'sentiment_yearly_main',
#  'kw_monthly_main']

# %% [markdown]
# We have a new collection, **kw_weekly_norm**.

# %%
kw_weekly = db['kw_weekly_norm']

# %%
for doc in kw_weekly.find():
    print(doc)
# Out:
# {'_id': {'year_week': ['2022', '39']}, 'kw_weights': {'cheese': 87, 'fries': 78, 'burger king': 69, 'fuck burger king': 65, 'donut lemon burger': 53, 'mcdonald’s&gt;&gt;&gt;burger king': 48, 'french fries': 45, 'burger': 34, 'curly fries': 32, 'cheese man lol': 30, 'charge burger': 24, 'big cheese board': 22, 'warren burger': 21, 'flavor fries': 20, 'dairy queen merger': 19, 'nacho fries': 19, 'british cheese': 19, 'barbecue sauce': 18, 'best fastfood': 18, 'jollibee sundae': 18, 'skanky burger': 17, 'fast food restaurants': 17, 'crazy day': 17, 'chili cheese burger': 16, 'wet naps': 16, 'version ver birthday merch star selca selfie pc photocard non': 16, 'local street food': 15, 'burger king bruh': 15, 'cheese steak fries': 15, 'france lol': 15, 'cheese market': 15, 'sad girl era': 14, 'money': 14, 'smn burger': 14, 'findom goddess paypig finsub brat': 14, 'taco bell': 14, 'outer mongolia': 14, 'burger ya kfc ke buns': 13, 'inappropriate office conduct': 13, 'burger ka sakin': 13, '
# ...

# %%
kw_weekly.count_documents({})
# Out:
# 1

# %% [markdown]
# We can now run the script for all the weeks we have available.

# %%
for doc in kw_weekly.find():
    print(doc)
# Out:
# {'_id': {'year_week': ['2022', '39']}, 'kw_weights': {'cheese': 87, 'fries': 78, 'burger king': 69, 'fuck burger king': 65, 'donut lemon burger': 53, 'mcdonald’s&gt;&gt;&gt;burger king': 48, 'french fries': 45, 'burger': 34, 'curly fries': 32, 'cheese man lol': 30, 'charge burger': 24, 'big cheese board': 22, 'warren burger': 21, 'flavor fries': 20, 'dairy queen merger': 19, 'nacho fries': 19, 'british cheese': 19, 'barbecue sauce': 18, 'best fastfood': 18, 'jollibee sundae': 18, 'skanky burger': 17, 'fast food restaurants': 17, 'crazy day': 17, 'chili cheese burger': 16, 'wet naps': 16, 'version ver birthday merch star selca selfie pc photocard non': 16, 'local street food': 15, 'burger king bruh': 15, 'cheese steak fries': 15, 'france lol': 15, 'cheese market': 15, 'sad girl era': 14, 'money': 14, 'smn burger': 14, 'findom goddess paypig finsub brat': 14, 'taco bell': 14, 'outer mongolia': 14, 'burger ya kfc ke buns': 13, 'inappropriate office conduct': 13, 'burger ka sakin': 13, '
# ...

# %%
kw_weekly.count_documents({})
# Out:
# 4

# %% [markdown]
# #### 4. Aggregate keyword extraction results per month

# %% [markdown]
# After running the kw_extraction.py script for the monthly aggregation ("09"), we get:

# %%
db.list_collection_names()
# Out:
# ['sentiment_monthly_main',
#  'data_test',
#  'emotions_weekly_main',
#  'kw_freq_weight_monthly_test',
#  'kw_freq_weight_test',
#  'kw_weekly_norm',
#  'kw_freq_weight_annually_test',
#  'kw_monthly_norm',
#  'client_info',
#  'sentiment_monthly_test',
#  'kw_daily_main',
#  'kw_freq_weight_daily_test',
#  'emotions_test',
#  'sentiment_annually_test',
#  'emotions_daily_main',
#  'sentiment_weekly_test',
#  'sentiment_weekly_main',
#  'data_twitter',
#  'kw_freq_weight_test_norm',
#  'emotions_yearly_main',
#  'sentiment_test',
#  'emotions_monthly_main',
#  'kw_yearly_main',
#  'sentiment_daily_test',
#  'kw_daily_norm',
#  'sentiment_daily_main',
#  'kw_freq_weight_weekly_test',
#  'kw_weekly_main',
#  'sentiment_yearly_main',
#  'kw_monthly_main']

# %% [markdown]
# We have a new collection, **kw_monthly_norm**.

# %%
kw_monthly = db['kw_monthly_norm']

# %%
for doc in kw_monthly.find():
    print(doc)
# Out:
# {'_id': {'year_month': ['2022', '09']}, 'kw_weights': {'fries': 78, 'cheese': 74, 'burger king': 69, 'fuck burger king': 65, 'donut lemon burger': 53, 'burger': 51, 'mcdonald’s&gt;&gt;&gt;burger king': 48, 'french fries': 45, 'curly fries': 32, 'cheese man lol': 30, 'charge burger': 24, 'warren burger': 21, 'chili cheese burger': 21, 'flavor fries': 20, 'dairy queen merger': 19, 'cheese steak fries': 19, 'nacho fries': 19, 'british cheese': 19, 'barbecue sauce': 18, 'best fastfood': 18, 'jollibee sundae': 18, 'skanky burger': 17, 'fast food restaurants': 17, 'crazy day': 17, 'wet naps': 16, 'version ver birthday merch star selca selfie pc photocard non': 16, 'local street food': 15, 'burger king bruh': 15, 'france lol': 15, 'cheese market': 15, 'sad girl era': 14, 'money': 14, 'smn burger': 14, 'nah good': 14, 'findom goddess paypig finsub brat': 14, 'taco bell': 14, 'outer mongolia': 14, 'burger ya kfc ke buns': 13, 'inappropriate office conduct': 13, 'burger ka sakin': 13, 'south w
# ...

# %%
kw_monthly.count_documents({})
# Out:
# 1

# %% [markdown]
# We can now run the script for all the months we have available.

# %%
for doc in kw_monthly.find():
    print(doc)
# Out:
# {'_id': {'year_month': ['2022', '09']}, 'kw_weights': {'fries': 78, 'cheese': 74, 'burger king': 69, 'fuck burger king': 65, 'donut lemon burger': 53, 'burger': 51, 'mcdonald’s&gt;&gt;&gt;burger king': 48, 'french fries': 45, 'curly fries': 32, 'cheese man lol': 30, 'charge burger': 24, 'warren burger': 21, 'chili cheese burger': 21, 'flavor fries': 20, 'dairy queen merger': 19, 'cheese steak fries': 19, 'nacho fries': 19, 'british cheese': 19, 'barbecue sauce': 18, 'best fastfood': 18, 'jollibee sundae': 18, 'skanky burger': 17, 'fast food restaurants': 17, 'crazy day': 17, 'wet naps': 16, 'version ver birthday merch star selca selfie pc photocard non': 16, 'local street food': 15, 'burger king bruh': 15, 'france lol': 15, 'cheese market': 15, 'sad girl era': 14, 'money': 14, 'smn burger': 14, 'nah good': 14, 'findom goddess paypig finsub brat': 14, 'taco bell': 14, 'outer mongolia': 14, 'burger ya kfc ke buns': 13, 'inappropriate office conduct': 13, 'burger ka sakin': 13, 'south w
# ...

# %%
kw_monthly.count_documents({})
# Out:
# 2

# %% [markdown]
# #### 5. Aggregate keyword extraction results per year

# %% [markdown]
# After running the kw_extraction.py script for the yearly aggregation ("2022"), we get:

# %%
db.list_collection_names()
# Out:
# ['sentiment_monthly_main',
#  'data_test',
#  'emotions_weekly_main',
#  'kw_freq_weight_monthly_test',
#  'kw_freq_weight_test',
#  'kw_weekly_norm',
#  'kw_freq_weight_annually_test',
#  'client_info',
#  'sentiment_monthly_test',
#  'kw_daily_main',
#  'kw_freq_weight_daily_test',
#  'emotions_test',
#  'sentiment_annually_test',
#  'emotions_daily_main',
#  'sentiment_weekly_test',
#  'sentiment_weekly_main',
#  'data_twitter',
#  'kw_freq_weight_test_norm',
#  'emotions_yearly_main',
#  'kw_monthly_norm',
#  'sentiment_test',
#  'emotions_monthly_main',
#  'kw_yearly_main',
#  'sentiment_daily_test',
#  'kw_daily_norm',
#  'kw_yearly_norm',
#  'sentiment_daily_main',
#  'kw_freq_weight_weekly_test',
#  'kw_weekly_main',
#  'sentiment_yearly_main',
#  'kw_monthly_main']

# %% [markdown]
# We have a new collection, **kw_yearly_norm**.

# %%
kw_yearly = db['kw_yearly_norm']

# %%
for doc in kw_yearly.find():
    print(doc)
# Out:
# {'_id': {'year': '2022'}, 'kw_weights': {'cheese': 68, 'deep shit blueberry bacon': 68, 'fuck burger king': 65, 'fantastic burger': 59, 'burlington cheese coat factory': 57, 'burger king': 56, 'fries': 54, 'donut lemon burger': 53, 'bacon snatchen': 53, 'french fries': 50, 'ahh yeah baby': 49, 'mcdonald’s&gt;&gt;&gt;burger king': 48, 'burger': 42, 'smoked cheese pizza': 41, 'underrated graceland fries': 40, 'best fries': 39, 'sheet pan smashburger fries': 38, 'butter roll w/ bacon': 36, 'direct cheese planner reinvent marketing british mississippi diverse illinois': 35, 'murican cheese': 33, 'chicken bacon swiss': 33, 'bacon sandwich': 32, 'thin crispy fries': 32, 'burger paket large sama sundae coklat': 32, 'good luck bacon': 32, 'cheese man lol': 30, 'cottage cheese b1 proteine wsh': 30, 'las smash burger': 30, 'bant bin bore burger bing burger bis bomeone': 30, 'overcooked durrrr burger taste': 29, 'shack shack burger': 29, 'cream cheese w honey': 29, 'snackin bacon': 28, 'home fr
# ...

# %%
kw_yearly.count_documents({})
# Out:
# 1

# %% [markdown]
# Everything is working as expected, but we want to make the following changes to our approach:
# - exclude terms with more than 3 words from our dictionaries of keywords
# - make a change to the way we are calculating our aggregations: the values should be divided by the number of days/weeks/months/years we are considering and not by the number of times each word is identified and associated with a certain weight - when a keyword is not identified in a certain day its weight should be considered to be zero

# %% [markdown]
# #### 6. Perform keyword extraction on a daily basis for n-grams with n < 4

# %%
db['kw_freq_weight_test_norm'].drop()

# %%
kw_norm = db['kw_freq_weight_test_norm']

# %%
# results for one day

for doc in kw_norm.find():
    print(doc)
# Out:
# {'_id': ObjectId('6399980cb09d60b61b5d23b0'), 'kw_weights': {'burger': 100, 'burger king': 69, 'fuck burger king': 65, 'fries': 57, 'donut lemon burger': 53, 'mcdonald’s&gt;&gt;&gt;burger king': 48, 'french fries': 38, 'curly fries': 32, 'charge burger': 24, 'warren burger': 21, 'chili cheese burger': 21, 'flavor fries': 20, 'dairy queen merger': 19, 'skanky burger': 17, 'fast food restaurants': 17, 'crazy day': 17, 'wet naps': 16, 'local street food': 15, 'burger king bruh': 15, 'sad girl era': 14, 'money': 14, 'smn burger': 14, 'inappropriate office conduct': 13, 'burger ka sakin': 13, 'american burger cheese': 13, 'super delicious burger': 13, 'water level': 12, 'big otsu': 12, 'burger king staff': 12, 'burger joint': 11, 'amp': 10, 'cheese burger': 10, 'big ass burger': 10, 'nothin burger': 10, 'big guy': 9, 'angel': 9, 'wrong': 9, 'cold burger': 9, 'people': 9, 'late night': 9, 'burgers': 8, 'best burger joint': 8, 'time': 8, 'large man': 8, 'whataburger': 8, 'small': 8, 'second
# ...

# %%
for doc in kw_norm.find():
    print(doc['extracted_at'])
# Out:
# 2022-09-29

# %%
kw_norm.count_documents({})
# Out:
# 1

# %%
# after running the script for all the available days

kw_norm.count_documents({})
# Out:
# 21

# %%
for doc in kw_norm.find():
    print(doc)
# Out:
# {'_id': ObjectId('6399980cb09d60b61b5d23b0'), 'kw_weights': {'burger': 100, 'burger king': 69, 'fuck burger king': 65, 'fries': 57, 'donut lemon burger': 53, 'mcdonald’s&gt;&gt;&gt;burger king': 48, 'french fries': 38, 'curly fries': 32, 'charge burger': 24, 'warren burger': 21, 'chili cheese burger': 21, 'flavor fries': 20, 'dairy queen merger': 19, 'skanky burger': 17, 'fast food restaurants': 17, 'crazy day': 17, 'wet naps': 16, 'local street food': 15, 'burger king bruh': 15, 'sad girl era': 14, 'money': 14, 'smn burger': 14, 'inappropriate office conduct': 13, 'burger ka sakin': 13, 'american burger cheese': 13, 'super delicious burger': 13, 'water level': 12, 'big otsu': 12, 'burger king staff': 12, 'burger joint': 11, 'amp': 10, 'cheese burger': 10, 'big ass burger': 10, 'nothin burger': 10, 'big guy': 9, 'angel': 9, 'wrong': 9, 'cold burger': 9, 'people': 9, 'late night': 9, 'burgers': 8, 'best burger joint': 8, 'time': 8, 'large man': 8, 'whataburger': 8, 'small': 8, 'second
# ...

# %% [markdown]
# #### 7. Aggregate keyword extraction results per day

# %%
db['kw_daily_norm'].drop()

# %%
kw_daily = db['kw_daily_norm']

# %%
# results for one day

for doc in kw_daily.find():
    print(doc)
# Out:
# {'_id': ObjectId('63999ccaf75e381fd92758b5'), 'extracted_at': '2022-09-29', 'year': '2022', 'month': '09', 'week_of_year': '39', 'kw_weights': {'burger': 100, 'burger king': 69, 'fuck burger king': 65, 'fries': 57, 'donut lemon burger': 53, 'mcdonald’s&gt;&gt;&gt;burger king': 48, 'french fries': 38, 'curly fries': 32, 'charge burger': 24, 'warren burger': 21, 'chili cheese burger': 21, 'flavor fries': 20, 'dairy queen merger': 19, 'skanky burger': 17, 'fast food restaurants': 17, 'crazy day': 17, 'wet naps': 16, 'local street food': 15, 'burger king bruh': 15, 'sad girl era': 14, 'money': 14, 'smn burger': 14, 'inappropriate office conduct': 13, 'burger ka sakin': 13, 'american burger cheese': 13, 'super delicious burger': 13, 'water level': 12, 'big otsu': 12, 'burger king staff': 12, 'burger joint': 11, 'amp': 10, 'cheese burger': 10, 'big ass burger': 10, 'nothin burger': 10, 'big guy': 9, 'angel': 9, 'wrong': 9, 'cold burger': 9, 'people': 9, 'late night': 9, 'burgers': 8, 'best
# ...

# %%
kw_daily.count_documents({})
# Out:
# 1

# %%
# after running the script for all the available days

for doc in kw_daily.find():
    print(doc)
# Out:
# {'_id': ObjectId('63999ccaf75e381fd92758b5'), 'extracted_at': '2022-09-29', 'year': '2022', 'month': '09', 'week_of_year': '39', 'kw_weights': {'burger': 100, 'burger king': 69, 'fuck burger king': 65, 'fries': 57, 'donut lemon burger': 53, 'mcdonald’s&gt;&gt;&gt;burger king': 48, 'french fries': 38, 'curly fries': 32, 'charge burger': 24, 'warren burger': 21, 'chili cheese burger': 21, 'flavor fries': 20, 'dairy queen merger': 19, 'skanky burger': 17, 'fast food restaurants': 17, 'crazy day': 17, 'wet naps': 16, 'local street food': 15, 'burger king bruh': 15, 'sad girl era': 14, 'money': 14, 'smn burger': 14, 'inappropriate office conduct': 13, 'burger ka sakin': 13, 'american burger cheese': 13, 'super delicious burger': 13, 'water level': 12, 'big otsu': 12, 'burger king staff': 12, 'burger joint': 11, 'amp': 10, 'cheese burger': 10, 'big ass burger': 10, 'nothin burger': 10, 'big guy': 9, 'angel': 9, 'wrong': 9, 'cold burger': 9, 'people': 9, 'late night': 9, 'burgers': 8, 'best
# ...

# %%
kw_daily.count_documents({})
# Out:
# 21

# %% [markdown]
# #### 8. Aggregate keyword extraction results per week

# %%
db['kw_weekly_norm'].drop()

# %%
kw_weekly = db['kw_weekly_norm']

# %%
# results for one week

for doc in kw_weekly.find():
    print(doc)
# Out:
# {'_id': {'year_week': ['2022', '39']}, 'kw_weights': {'cheese': 58, 'fries': 52, 'burger': 34, 'french fries': 30, 'burger king': 23, 'fuck burger king': 22, 'donut lemon burger': 18, 'mcdonald’s&gt;&gt;&gt;burger king': 16, 'curly fries': 11, 'chili cheese burger': 11, 'cheese man lol': 10, 'cheese steak fries': 10, 'amp': 9, 'charge burger': 8, 'warren burger': 7, 'flavor fries': 7, 'nah good': 7, 'big cheese board': 7, 'dairy queen merger': 6, 'skanky burger': 6, 'fast food restaurants': 6, 'crazy day': 6, 'time': 6, 'nacho fries': 6, 'british cheese': 6, 'barbecue sauce': 6, 'best fastfood': 6, 'jollibee sundae': 6, 'hot wings sauce': 6, 'cheese pizza leaks': 6, 'discord leaks': 6, 'best discord server': 6, 'mozzarella cheese': 6, 'wet naps': 5, 'local street food': 5, 'burger king bruh': 5, 'sad girl era': 5, 'money': 5, 'smn burger': 5, 'best burger joint': 5, 'small': 5, 'cost': 5, 'france lol': 5, 'cheese market': 5, 'taco bell': 5, 'outer mongolia': 5, 'mac cheese': 5, 'frid
# ...

# %%
kw_weekly.count_documents({})
# Out:
# 1

# %%
# after running the script for all the available weeks

for doc in kw_weekly.find():
    print(doc)
# Out:
# {'_id': {'year_week': ['2022', '39']}, 'kw_weights': {'cheese': 58, 'fries': 52, 'burger': 34, 'french fries': 30, 'burger king': 23, 'fuck burger king': 22, 'donut lemon burger': 18, 'mcdonald’s&gt;&gt;&gt;burger king': 16, 'curly fries': 11, 'chili cheese burger': 11, 'cheese man lol': 10, 'cheese steak fries': 10, 'amp': 9, 'charge burger': 8, 'warren burger': 7, 'flavor fries': 7, 'nah good': 7, 'big cheese board': 7, 'dairy queen merger': 6, 'skanky burger': 6, 'fast food restaurants': 6, 'crazy day': 6, 'time': 6, 'nacho fries': 6, 'british cheese': 6, 'barbecue sauce': 6, 'best fastfood': 6, 'jollibee sundae': 6, 'hot wings sauce': 6, 'cheese pizza leaks': 6, 'discord leaks': 6, 'best discord server': 6, 'mozzarella cheese': 6, 'wet naps': 5, 'local street food': 5, 'burger king bruh': 5, 'sad girl era': 5, 'money': 5, 'smn burger': 5, 'best burger joint': 5, 'small': 5, 'cost': 5, 'france lol': 5, 'cheese market': 5, 'taco bell': 5, 'outer mongolia': 5, 'mac cheese': 5, 'frid
# ...

# %%
kw_weekly.count_documents({})
# Out:
# 4

# %% [markdown]
# #### 9. Aggregate keyword extraction results per month

# %%
db['kw_monthly_norm'].drop()

# %%
kw_monthly = db['kw_monthly_norm']

# %%
# results for one week

for doc in kw_monthly.find():
    print(doc)
# Out:
# {'_id': {'year_month': ['2022', '09']}, 'kw_weights': {'fries': 78, 'burger': 51, 'french fries': 45, 'cheese': 37, 'burger king': 34, 'fuck burger king': 32, 'donut lemon burger': 26, 'mcdonald’s&gt;&gt;&gt;burger king': 24, 'curly fries': 16, 'cheese man lol': 15, 'charge burger': 12, 'amp': 11, 'warren burger': 10, 'chili cheese burger': 10, 'flavor fries': 10, 'dairy queen merger': 10, 'cheese steak fries': 10, 'nacho fries': 10, 'british cheese': 10, 'barbecue sauce': 9, 'best fastfood': 9, 'jollibee sundae': 9, 'skanky burger': 8, 'fast food restaurants': 8, 'crazy day': 8, 'wet naps': 8, 'local street food': 8, 'burger king bruh': 8, 'best burger joint': 8, 'time': 8, 'small': 8, 'cost': 8, 'france lol': 8, 'cheese market': 8, 'sad girl era': 7, 'money': 7, 'smn burger': 7, 'nah good': 7, 'taco bell': 7, 'outer mongolia': 7, 'inappropriate office conduct': 6, 'burger ka sakin': 6, 'american burger cheese': 6, 'super delicious burger': 6, 'water level': 6, 'big otsu': 6, 'burge
# ...

# %%
kw_monthly.count_documents({})
# Out:
# 1

# %%
# after running the script for all the available weeks

for doc in kw_monthly.find():
    print(doc)
# Out:
# {'_id': {'year_month': ['2022', '09']}, 'kw_weights': {'fries': 78, 'burger': 51, 'french fries': 45, 'cheese': 37, 'burger king': 34, 'fuck burger king': 32, 'donut lemon burger': 26, 'mcdonald’s&gt;&gt;&gt;burger king': 24, 'curly fries': 16, 'cheese man lol': 15, 'charge burger': 12, 'amp': 11, 'warren burger': 10, 'chili cheese burger': 10, 'flavor fries': 10, 'dairy queen merger': 10, 'cheese steak fries': 10, 'nacho fries': 10, 'british cheese': 10, 'barbecue sauce': 9, 'best fastfood': 9, 'jollibee sundae': 9, 'skanky burger': 8, 'fast food restaurants': 8, 'crazy day': 8, 'wet naps': 8, 'local street food': 8, 'burger king bruh': 8, 'best burger joint': 8, 'time': 8, 'small': 8, 'cost': 8, 'france lol': 8, 'cheese market': 8, 'sad girl era': 7, 'money': 7, 'smn burger': 7, 'nah good': 7, 'taco bell': 7, 'outer mongolia': 7, 'inappropriate office conduct': 6, 'burger ka sakin': 6, 'american burger cheese': 6, 'super delicious burger': 6, 'water level': 6, 'big otsu': 6, 'burge
# ...

# %%
kw_monthly.count_documents({})
# Out:
# 2

# %% [markdown]
# #### 10. Aggregate keyword extraction results per year

# %%
db['kw_yearly_norm'].drop()

# %%
kw_yearly = db['kw_yearly_norm']

# %%
for doc in kw_yearly.find():
    print(doc)
# Out:
# {'_id': {'year': '2022'}, 'kw_weights': {'fries': 48, 'cheese': 48, 'burger': 34, 'french fries': 30, 'burger king': 22, 'fuck burger king': 16, 'bacon': 14, 'donut lemon burger': 13, 'mcdonald’s&gt;&gt;&gt;burger king': 12, 'amp': 11, 'curly fries': 8, 'cheese man lol': 8, 'bacon sandwich': 8, 'charge burger': 6, 'chili cheese burger': 6, 'cheese steak fries': 6, 'cheese pizza leaks': 6, 'discord leaks': 6, 'best discord server': 6, 'warren burger': 5, 'flavor fries': 5, 'dairy queen merger': 5, 'nacho fries': 5, 'british cheese': 5, 'time': 5, 'barbecue sauce': 4, 'best fastfood': 4, 'jollibee sundae': 4, 'skanky burger': 4, 'fast food restaurants': 4, 'crazy day': 4, 'wet naps': 4, 'local street food': 4, 'burger king bruh': 4, 'best burger joint': 4, 'small': 4, 'cost': 4, 'france lol': 4, 'cheese market': 4, 'sad girl era': 4, 'money': 4, 'smn burger': 4, 'nah good': 4, 'taco bell': 4, 'outer mongolia': 4, 'real': 4, 'cheese burger': 4, 'blue cheese': 4, 'good': 4, 'fridge': 4, 
# ...

# %%
kw_yearly.count_documents({})
# Out:
# 1

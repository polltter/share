# %% [markdown]
# # C-More

# %% [markdown]
# ### MongoDB

# %%
import pymongo

# %%
client = pymongo.MongoClient('mongodb://localhost:27017/')

# %% [raw]
# client.list_database_names()

# %% [markdown]
# #### 1. Create database

# %%
# create database rep_analysis_new

db = client['rep_analysis_new']

# %% [markdown]
# In MongoDB, a **database** is not created until it gets content.

# %% [markdown]
# #### 2. Create collection

# %%
# create client_info collection (similar to an RDBMS table)

client_info = db['client_info']

# %%
db.list_collection_names()
# Out:
# []

# %% [markdown]
# In MongoDB, a **collection** is not created until it gets content.

# %%
# insert info defined by each client into collection client_info

new_client = {
    "company_name": "McDonald's", 
    "alternative_names": ["McDonald", "McDonalds", "Mac"], 
    "handles": [
        {
            "type": "twitter",
            "name": "McDonalds"
        },
        {
            "type": "facebook",
            "name": "..."
        },
        {
            "type": "linkedin",
            "name": "..."
        }
    ], 
    "language": "en", 
    "search_terms": ["burger", "fries", "cheese", "bacon"], 
    "competitors": ["Burger King", "KFC"]
}

result = client_info.insert_one(new_client)

# %%
result.inserted_id
# Out:
# ObjectId('6332d3537f6127fd30d1e241')

# %% [markdown]
# **P1:** deixamos estes ids serem definidos automaticamente?

# %% [markdown]
# **R1:** Sim.

# %%
db.list_collection_names()
# Out:
# ['client_info']

# %% [markdown]
# #### 3. Select data from a collection

# %%
for doc in client_info.find():
    print(doc)
# Out:
# {'_id': ObjectId('6332d3537f6127fd30d1e241'), 'company_name': "McDonald's", 'alternative_names': ['McDonald', 'McDonalds', 'Mac'], 'handles': [{'type': 'twitter', 'name': 'McDonalds'}, {'type': 'facebook', 'name': '...'}, {'type': 'linkedin', 'name': '...'}], 'language': 'en', 'search_terms': ['burger', 'fries', 'cheese', 'bacon'], 'competitors': ['Burger King', 'KFC']}

# %%
my_query = {"company_name": "McDonald's"}

for client in client_info.find(my_query, {"_id": 0, 
                                          "alternative_names": 0, 
                                          "handles": 0}):
    print(client)
# Out:
# {'company_name': "McDonald's", 'language': 'en', 'search_terms': ['burger', 'fries', 'cheese', 'bacon'], 'competitors': ['Burger King', 'KFC']}

# %%
# find search_terms for company McDonald's

my_query = {"company_name": "McDonald's"}

for client in client_info.find(my_query):
    print(client['search_terms'])
# Out:
# ['burger', 'fries', 'cheese', 'bacon']

# %% [markdown]
# #### 4. Check collections after running the .py script to get twitter data

# %%
# we've decided to rename the collection to data_twitter (it was named twitter_info)

db['twitter_info'].rename('data_twitter')
# Out:
# {'ok': 1.0}

# %%
db.list_collection_names()
# Out:
# ['data_twitter', 'client_info']

# %% [markdown]
# #### 5. Select data from the data_twitter collection

# %%
twitter_info = db['data_twitter']

# %%
for doc in twitter_info.find():
    print(doc)
# Out:
# {'_id': ObjectId('6332ded8239d27df11bd2017'), 'created_at': '2022-09-26T23:29:55.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}, 'text': 'Factory reset your circadian rhythm 101:\nEat something super unhealthy and inflammatory at 9pm like pizza/instant noodles/burger with tons of store bought mayo.\nSleep when you pass out.\n\nTA-DAAA !!', 'id': '1574541810738659328', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2018'), 'created_at': '2022-09-26T23:29:49.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'text': '@Buffpup_ Me looking at that burger like... https://t.co/5P8HH2uhLs', 'id': '1574541785900384256', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2019'), 'created_at': '2022-09-26T23:29:48.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}, 'text': '@FearTheFloof As a fellow child of the 80s, I couldn’t be less worried about that.  Huge nothing burger.', 'id': '1574541780405702670', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd201a'), 'created_at': '2022-09-26T23:29:39.000Z', 'public_metrics': {'retweet_count': 7, 'reply_count': 137, 'like_count': 79, 'quote_count': 26}, 'text': 'Which 3 toppings are you adding to your Burger? https://t.co/qDKb8gjGfi', 'id': '1574541743584088064', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd201b'), 'created_at': '2022-09-26T23:29:27.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 2, 'like_count': 3, 'quote_count': 0}, 'text': '@Smollbrainarti2 @kawaii_blue368 You should always wash your pizza before eating it to remove the grease and eat the burger with the paper, it adds more flavor', 'id': '1574541692476174336', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd201c'), 'created_at': '2022-09-26T23:29:16.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 1, 'like_count': 4, 'quote_count': 0}, 'text': '@hoyahugs Burger enemy burger bad for health burger cruel ana say no burger 🤒🤬😡😤👎🏽', 'id': '1574541646498353170', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd201d'), 'created_at': '2022-09-26T23:29:16.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'text': '@SamSykesSwears They tore it down and replaced it with a heavily gentrified neighborhood plus a Burger King. 🥺', 'id': '1574541644900323336', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd201e'), 'created_at': '2022-09-26T23:29:02.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}, 'text': 'Hurricane Nothing-burger Ian.    \n\nNothing to see here.', 'id': '1574541585848717335', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd201f'), 'created_at': '2022-09-26T23:28:53.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 1, 'like_count': 0, 'quote_count': 0}, 'text': '@burger_76 Sending good vibes your way!', 'id': '1574541550872592384', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2020'), 'created_at': '2022-09-26T23:28:49.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}, 'text': '@g1rlhenryrollns Cheap beer,  stale smoke, and yesterday’s Burger King.', 'id': '1574541532157607938', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2021'), 'created_at': '2022-09-26T23:28:46.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0
_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'text': 'I hate my cravings when Mother Nature be in town. It’s always a double cheese burger from McDonald’s. I haven’t given in to these cravings since college. But right now?! It’s killing me 😭😭', 'id': '1574540935974756352', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd203e'), 'created_at': '2022-09-26T23:25:58.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 2, 'like_count': 4, 'quote_count': 0}, 'text': '@spursmark8 @MiniT46 Probably some dirty burger from my favourite Burger joint🤣.. I’m not very fussy with food!', 'id': '1574540816504483840', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd203f'), 'created_at': '2022-09-26T23:25:44.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'text': '@raleyclub @azcentral Nothing burger. Jeff Ellington, the CEO of Runbeck is on record saying they got those ballots and they were processed to standard. Its likely theyre twisting Gilbertsons words saying they were scanned for "tabulation". They do scan them for tracking before sending to Runbeck', 'id': '1574540756613705728', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2040'), 'created_at': '2022-09-26T23:25:32.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'text': 'fkkk now i’m craving for samurai burger', 'id': '1574540707166965760', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2041'), 'created_at': '2022-09-26T23:25:29.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 1, 'like_count': 0, 'quote_count': 0}, 'text': '@zaquebb @meth_boolin @doodoo_burger @sanjiviyer10 @ThyEx @Kaostanza Still im just a sad poor gold 1 maybe im just not understanding', 'id': '1574540695272304640', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2042'), 'created_at': '2022-09-26T23:25:28.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'text': '@WalshFreedom Matt Gaetz is a nothing burger.', 'id': '1574540690217836545', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2043'), 'created_at': '2022-09-26T23:25:24.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 1, 'like_count': 7, 'quote_count': 0}, 'text': 'okay mr. mingus bob burger 😆\nhttps://t.co/ZWoMBtCfs7', 'id': '1574540673381826560', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2044'), 'created_at': '2022-09-26T23:25:24.000Z', 'public_metrics': {'retweet_count': 1, 'reply_count': 1, 'like_count': 3, 'quote_count': 0}, 'text': 'Camembert burger erupts when you take a bite', 'id': '1574540673180749846', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2045'), 'created_at': '2022-09-26T23:25:12.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}, 'text': 'Eating junk food i.e. pizza, burger, fries, chocolate and etc .. will cause inflammatory damages to brain. Eating clean will completely erase it.', 'id': '1574540624065626112', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2046'), 'created_at': '2022-09-26T23:25:10.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'text': 'Burger eaten... Kinda bored.... I should be toxic to n hit her with the "wyd" text', 'id': '1574540612388298753', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2047'), 'created_at': '2022-09-26T23:25:00.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'text': 'Camembert burger erupts when you take a bite', 'id': '1574540570982338564', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2048'), 'created_at': '2022-09-26T23:24:40.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'text': '@keyon To be fair it was Burger King uk lol', 'id': '1574540486039126017', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2049'), 'created_at': '2022-09-26T23:24:36.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}, 'text': "@loresjoberg The thing is, both possibilities are terrifying to me. The first, because it implies we're never going to know. The second, because it implies that somehow we *are* different and special - that there's a special sauce in us that not every burger gets.", 'id': '1574540471241580545', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd204a'), 'created_at': '2022-09-26T23:24:07.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 3, 'like_count': 0, 'quote_count': 0}, 'text': '@zaquebb @meth_boolin @doodoo_burger @sanjiviyer10 @ThyEx @Kaostanza Just my opinion', 'id': '1574540348185104404', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd204b'), 'created_at': '2022-09-26T23:24:03.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'text': '@halomancer1 mmmm burger', 'id': '1574540334516043776', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd204c'), 'created_at': '2022-09-26T23:24:03.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 1, 'like_count': 2, 'quote_count': 0}, 'text': '@MikeTaylorShow Taylor I know your Puro… been listening to you for over a decade. I’m a good husband and puro for my wife but if she quit her job and never showered, and ate Burger King all day… I may show some dislike to all that. Hell if they ain’t interesting than that’s bc they ain’t!', 'id': '1574540333114970153', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd204d'), 'created_at': '2022-09-26T23:23:27.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 1, 'like_count': 2, 'quote_count': 0}, 'text': "@KetoBeejay wtf are you doing? that's not a cheeses burger that's an I ran out of cheese midway.", 'id': '1574540183118270488', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd204e'), 'created_at': '2022-09-26T23:23:25.000Z', 'public_metrics': {'retweet_count': 7, 'reply_count': 0, 'like_count': 21, 'quote_count': 0}, 'text': 'Virgin Mulan Sauce Vs Chad Lupin Burger https://t.co/CROQ7XaP28', 'id': '1574540174687719437', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd204f'), 'created_at': '2022-09-26T23:23:20.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}, 'text': '@NoOtherJess True. They’re hard to get into though. I’m thinking smaller though. Maybe like Zaxby’s, Gusto, bubble tea, Cinnabon, or Chinese. Anything not burger or cafe related.', 'id': '1574540153116413956', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2050'), 'created_at': '2022-09-26T23:23:20.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0
_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2087'), 'id': '1574538337473335296', 'lang': 'en', 'text': 'Being able to walk across the street and get a veggie burger at 3am is such a blessing. I love LA.', 'created_at': '2022-09-26T23:16:07.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 1, 'like_count': 28, 'quote_count': 0}, 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2088'), 'id': '1574538313658413056', 'lang': 'en', 'text': "@stories4coffee I have a handful of staple meals I know I can eat so when people ask me what can I eat, I can be like, yeah, as long as they have a burger I'm good.", 'created_at': '2022-09-26T23:16:02.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2089'), 'id': '1574538309132767232', 'lang': 'en', 'text': "@kingojungle I didn't order this s..t burger.", 'created_at': '2022-09-26T23:16:01.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 2, 'quote_count': 0}, 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd208a'), 'id': '1574538295085867008', 'lang': 'en', 'text': '@NickAdamsinUSA Trump is so clean came after him 8 times  nothing burger you communist bastards .', 'created_at': '2022-09-26T23:15:57.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd208b'), 'id': '1574538291788931073', 'lang': 'en', 'text': '@graue @skinnylatte @Veganburg I feel like the SF location used to have limited time special burgers but I don’t see that they offer them anymore. Their website says the Singapore location also has a char-grilled satay burger that sounds lovely.', 'created_at': '2022-09-26T23:15:56.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 1, 'like_count': 2, 'quote_count': 0}, 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd208c'), 'id': '1574538273179029525', 'lang': 'en', 'text': 'Best burger in the state of FL 🤟 https://t.co/VKs6QiTQ9d', 'created_at': '2022-09-26T23:15:52.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 2, 'like_count': 10, 'quote_count': 0}, 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd208d'), 'id': '1574538273069965312', 'lang': 'en', 'text': '@bourbonislife80 @BumglovesK They use stem cell generated heme iron in the fake burger meat...from animals😂', 'created_at': '2022-09-26T23:15:52.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}, 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd208e'), 'id': '1574538258297782272', 'lang': 'en', 'text': "@OPRfan @AniseNot I've enjoyed a fried egg on occasion, but the ideal burger still doesn't have it.\n\nBacon on a burger is some bullshit. Just gets in the way and adds nothing of value.", 'created_at': '2022-09-26T23:15:48.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}, 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd208f'), 'id': '1574538195257085952', 'lang': 'en', 'text': 'They said dis nigga switched to da impossible burger😂 https://t.co/h1OxgzGUu7', 'created_at': '2022-09-26T23:15:33.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2090'), 'id': '1574538168019615746', 'lang': 'en', 'text': 'can i get the impossible burger thanks', 'created_at': '2022-09-26T23:15:27.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0
_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'id': '1574534334559801347', 'lang': 'en', 'text': 'One Bacon Bit a day keeps support at bay! Learn about Bacon’s new MDM Manual Enrollment Profile Feature with Bacon 4.1. in this week’s Bacon Bits.\n \nCheck out our YouTube channel for all our Bacon Bits \nhttps://t.co/q4M7207rbD\n\n#MDM #BaconUnlimited #MadeByITPeopleForITPeople', 'created_at': '2022-09-26T23:00:13.000Z', 'search_word': 'bacon'}
# {'_id': ObjectId('6332dedf239d27df11bd250f'), 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'id': '1574534294525120512', 'lang': 'en', 'text': 'Have you heard of the Holy Trinity? Uh yeah bacon eggs and omelettes? 😂😂😂', 'created_at': '2022-09-26T23:00:03.000Z', 'search_word': 'bacon'}
# {'_id': ObjectId('6332dedf239d27df11bd2510'), 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'id': '1574534293459816470', 'lang': 'en', 'text': '@barbarab1974 Bacon', 'created_at': '2022-09-26T23:00:03.000Z', 'search_word': 'bacon'}
# {'_id': ObjectId('6332dedf239d27df11bd2511'), 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'id': '1574534292172308480', 'lang': 'en', 'text': 'Francis Bacon never tired of contrasting hot and cool tipstaff.', 'created_at': '2022-09-26T23:00:03.000Z', 'search_word': 'bacon'}
# {'_id': ObjectId('6332dedf239d27df11bd2512'), 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}, 'id': '1574534285070983168', 'lang': 'en', 'text': 'Add these Keto Bacon Breads 🥓🥯 to your #lowcarbkids toolbox and you’ll be the favourite every time 😉\n.\n.\n.\n#lowcarbrecipes #baconrecipes #bacon #ketokids #recipesforkids #ketofamilyrecipes #theketodiet https://t.co/lejlxMxAHu', 'created_at': '2022-09-26T23:00:01.000Z', 'search_word': 'bacon'}

# %%
# total number of documents

twitter_info.count_documents({})
# Out:
# 1276

# %% [markdown]
# We can create a text index to perform $text queries (https://www.mongodb.com/docs/manual/text-search/#on-premises-text-search).

# %%
twitter_info.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]}}

# %%
# create text index to perform $text queries
# https://stackoverflow.com/questions/33541290/how-can-i-create-an-index-with-pymongo
# https://pymongo.readthedocs.io/en/stable/api/pymongo/collection.html#pymongo.collection.Collection.create_index

twitter_info.create_index([('text', pymongo.TEXT)])
# Out:
# 'text_text'

# %%
twitter_info.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]},
#  'text_text': {'v': 2,
#   'key': [('_fts', 'text'), ('_ftsx', 1)],
#   'weights': SON([('text', 1)]),
#   'default_language': 'english',
#   'language_override': 'language',
#   'textIndexVersion': 3}}

# %%
cursor = twitter_info.find({"$text": {"$search": "McDonald's"}}, {"text": 1})

i=0

for x in cursor:
    i+=1
    print(x['text']+'\n'+'\n'+'-----')
    
print('\n --> ' + str(i) + ' documents in total')
# Out:
# I love me some reheated McDonald’s French fries
#
# -----
# @SjamaanN McDonald's Fries
# Wendy's Baconator
# Wendy's Frosty
#
# -----
# Jigen being a chronic smoker and only eating fries from McDonald's when they go is killing me
#
# -----
# McDonalds Hot Mustard &gt; Burger King Hot Mustard
#
# -----
# @Splenda @McDonalds Coffee with cream and a bacon, egg and cheese biscuit #NationalCoffeeDay
#
# -----
# @Splenda @McDonalds Coffee with cream and a bacon, egg and cheese biscuit #NationalCoffeeDay
#
# -----
# McDonald’s fries n a blunt&gt;&gt;&gt; 😩😩😩
#
# -----
# this orange soda at this cheese steak place is like a fanta equivalent for mcdonalds sprite
#
# -----
# @MadScientistFF Wendy’s baconator
# McDonald’s fries
# Cotton candy blizzard
#
# -----
# @Splenda @McDonalds Iced sugar free vanilla coffee with a Sausage egg and cheese biscuit.
#
# -----
# Just ate a 20 piece and 2 large fries from McDonald’s. Will I die?
#
# -----
# I love eating McDonalds double cheeseburger extra pickles with French fries extra salt
#
# -----
# @Splenda @McDonalds I always get their Caramel Frappucino with a Strawberry Cream Cheese Pie!! YUMMY!!  #NationalCoffeeDay
#
# -----
# @Splenda @McDonalds #NationalCoffeeDay Bacon Egg &amp; Cheese Bisquit and a small black coffee with Splenda for me please!!
#
# -----
# @Splenda @McDonalds #NationalCoffeeDay Bacon Egg &amp; Cheese Bisquit and a small black coffee with Splenda for me please!!
#
# -----
# @Splenda @McDonalds My favorite coffee ☕️ combo is bacon egg and cheese biscuit with a caramel iced coffee #NationalCoffeeDay
#
# -----
# @Splenda @McDonalds My favorite coffee ☕️ combo is bacon egg and cheese biscuit with a caramel iced coffee #NationalCoffeeDay
#
# -----
# @MadScientistFF McDonalds fries, Big Mac and I would say Mcflurry but we know that shit ain't working so gimme Wendy's frosty
#
# -----
# @nathaliejacoby1 Nope. No way and no how. O'Rourke is a clown and not even qualified to ask "you want fries with that" at the local McDonalds. He will never be a Governor, nor does he deserve to.
#
# -----
# ON OCTOBER 6TH, LET'S ALL GO TO MCDONALDS AND ASK FOR THE LUPIN BURGER
#
# THE LOOK ON THE WORKERS FACE WILL BE AWESOME! https://t.co/7e5MCTELIr
#
# -----
# LUPIN MEAL AT MCDONALDS?!?!?! I'M GONNA CRY I NEED TO HAVE ONE.. I NEED TO GO TO JAPAN TO GET THE LUPIN BURGER https://t.co/7e5MCTELIr
#
# -----
# @JBPritzker Have you also noticed that retailers are replacing their cashiers with self service registers? Next will be McDonald's and Burger King, using Kiosks to replace their counter people.
#
# -----
# mcdonalds (fries served moldy, inside of nuggets, burger served with raw meat, inside ice cream machine still in use) https://t.co/pLkgYouMWg
#
# -----
# mcdonalds (fries served moldy, inside of nuggets, burger served with raw meat, inside ice cream machine still in use) https://t.co/pLkgYouMWg
#
# -----
# @Grubhub Hello, I just ordered food from the local @McDonalds thru the Grubhub app and it looks like the contents were tampered with. I can't receive a refund for total since I refunded the fries. This is quite ALARMING.
#
# -----
# Went to Hardee's today just to check it out . It wasn't very good. The cheese burger was cold and the cheese was too and my Wife and I were the only ones in the restaurant. I had a chocolate shake and McDonald's better. I give Hardee's one star. Probably won't try it again.
#
# -----
# I hate my cravings when Mother Nature be in town. It’s always a double cheese burger from McDonald’s. I haven’t given in to these cravings since college. But right now?! It’s killing me 😭😭
#
# -----
# Went to Hardee's today just to check it out . It wasn't very good. The cheese burger was cold and the cheese was too and my Wife and I were the only ones in the restaurant. I had a chocolate shake and McDonald's better. I give Hardee's one star. Probably won't try it again.
#
# -----
# I hate my cravings when Mother Nature be in town. It’s always a double cheese burger from McDonald’s. I haven’t given in to these cravings since college. But right now?! It’s killing me 😭😭
#
# -----
# Federal Reserve insider leaks classified image showing key CPI targets the fed is looking for before it halts rate increases,
#
# "we pull up the @McDonalds menu daily, the fries are no where near our target" - the insider said $dxy https://t.co/ZDk3KlsPWE
#
# -----
# Now they want me to run to front of bus when they have pay station more then once on bus that have usb dumb mad I went to McDonald's to get a free burger I did not tell them to give out 1500 main points if u download app and free shit dummies retards man
#
# -----
#
#  --> 31 documents in total

# %% [markdown]
# We get results for "McDonald's", "McDonald’s" and "McDonalds" (31 documents in total).
#
# For a better understanding of the results we get, we can use regular expressions instead. We can also drop the index if we don't intend to use it.

# %%
twitter_info.drop_index("text_text")

# %%
twitter_info.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]}}

# %%
import re

# %%
my_query = {"text": {"$regex": re.compile("mcdonald's", re.IGNORECASE)}}

cursor = twitter_info.find(my_query)

i=0

for x in cursor:
    i+=1
    print(x['text']+'\n'+'-----')
    
print('\n --> ' + str(i) + ' documents in total')
# Out:
# Now they want me to run to front of bus when they have pay station more then once on bus that have usb dumb mad I went to McDonald's to get a free burger I did not tell them to give out 1500 main points if u download app and free shit dummies retards man
# -----
# @JBPritzker Have you also noticed that retailers are replacing their cashiers with self service registers? Next will be McDonald's and Burger King, using Kiosks to replace their counter people.
# -----
# Went to Hardee's today just to check it out . It wasn't very good. The cheese burger was cold and the cheese was too and my Wife and I were the only ones in the restaurant. I had a chocolate shake and McDonald's better. I give Hardee's one star. Probably won't try it again.
# -----
# @SjamaanN McDonald's Fries
# Wendy's Baconator
# Wendy's Frosty
# -----
# Jigen being a chronic smoker and only eating fries from McDonald's when they go is killing me
# -----
# Went to Hardee's today just to check it out . It wasn't very good. The cheese burger was cold and the cheese was too and my Wife and I were the only ones in the restaurant. I had a chocolate shake and McDonald's better. I give Hardee's one star. Probably won't try it again.
# -----
#
#  --> 6 documents in total

# %%
my_query = {"text": {"$regex": re.compile("mcdonalds", re.IGNORECASE)}}

cursor = twitter_info.find(my_query)

i=0

for x in cursor:
    i+=1
    print(x['text']+'\n'+'-----')
    
print('\n --> ' + str(i) + ' documents in total')
# Out:
# McDonalds Hot Mustard &gt; Burger King Hot Mustard
# -----
# mcdonalds (fries served moldy, inside of nuggets, burger served with raw meat, inside ice cream machine still in use) https://t.co/pLkgYouMWg
# -----
# ON OCTOBER 6TH, LET'S ALL GO TO MCDONALDS AND ASK FOR THE LUPIN BURGER
#
# THE LOOK ON THE WORKERS FACE WILL BE AWESOME! https://t.co/7e5MCTELIr
# -----
# LUPIN MEAL AT MCDONALDS?!?!?! I'M GONNA CRY I NEED TO HAVE ONE.. I NEED TO GO TO JAPAN TO GET THE LUPIN BURGER https://t.co/7e5MCTELIr
# -----
# I love eating McDonalds double cheeseburger extra pickles with French fries extra salt
# -----
# @nathaliejacoby1 Nope. No way and no how. O'Rourke is a clown and not even qualified to ask "you want fries with that" at the local McDonalds. He will never be a Governor, nor does he deserve to.
# -----
# @Grubhub Hello, I just ordered food from the local @McDonalds thru the Grubhub app and it looks like the contents were tampered with. I can't receive a refund for total since I refunded the fries. This is quite ALARMING.
# -----
# mcdonalds (fries served moldy, inside of nuggets, burger served with raw meat, inside ice cream machine still in use) https://t.co/pLkgYouMWg
# -----
# Federal Reserve insider leaks classified image showing key CPI targets the fed is looking for before it halts rate increases,
#
# "we pull up the @McDonalds menu daily, the fries are no where near our target" - the insider said $dxy https://t.co/ZDk3KlsPWE
# -----
# @MadScientistFF McDonalds fries, Big Mac and I would say Mcflurry but we know that shit ain't working so gimme Wendy's frosty
# -----
# @Splenda @McDonalds My favorite coffee ☕️ combo is bacon egg and cheese biscuit with a caramel iced coffee #NationalCoffeeDay
# -----
# @Splenda @McDonalds #NationalCoffeeDay Bacon Egg &amp; Cheese Bisquit and a small black coffee with Splenda for me please!!
# -----
# this orange soda at this cheese steak place is like a fanta equivalent for mcdonalds sprite
# -----
# @Splenda @McDonalds Coffee with cream and a bacon, egg and cheese biscuit #NationalCoffeeDay
# -----
# @Splenda @McDonalds I always get their Caramel Frappucino with a Strawberry Cream Cheese Pie!! YUMMY!!  #NationalCoffeeDay
# -----
# @Splenda @McDonalds Iced sugar free vanilla coffee with a Sausage egg and cheese biscuit.
# -----
# @Splenda @McDonalds My favorite coffee ☕️ combo is bacon egg and cheese biscuit with a caramel iced coffee #NationalCoffeeDay
# -----
# @Splenda @McDonalds #NationalCoffeeDay Bacon Egg &amp; Cheese Bisquit and a small black coffee with Splenda for me please!!
# -----
# @Splenda @McDonalds Coffee with cream and a bacon, egg and cheese biscuit #NationalCoffeeDay
# -----
#
#  --> 19 documents in total

# %%
my_query = {"text": {"$regex": re.compile("mcdonald’s", re.IGNORECASE)}}

cursor = twitter_info.find(my_query)

i=0

for x in cursor:
    i+=1
    print(x['text']+'\n'+'-----')
    
print('\n --> ' + str(i) + ' documents in total')
# Out:
# I hate my cravings when Mother Nature be in town. It’s always a double cheese burger from McDonald’s. I haven’t given in to these cravings since college. But right now?! It’s killing me 😭😭
# -----
# I love me some reheated McDonald’s French fries
# -----
# @MadScientistFF Wendy’s baconator
# McDonald’s fries
# Cotton candy blizzard
# -----
# Just ate a 20 piece and 2 large fries from McDonald’s. Will I die?
# -----
# McDonald’s fries n a blunt&gt;&gt;&gt; 😩😩😩
# -----
# I hate my cravings when Mother Nature be in town. It’s always a double cheese burger from McDonald’s. I haven’t given in to these cravings since college. But right now?! It’s killing me 😭😭
# -----
#
#  --> 6 documents in total

# %% [markdown]
# The 6 + 19 + 6 documents that we get add to 31 documents (the same number that we got with our text search).

# %% [markdown]
# **P2:** É preferível usar expressões regulares ou queremos usar o "text index" do MongoDB?

# %% [markdown]
# **R2:** Usar expressões regulares.

# %% [markdown]
# If we would like to use two conditions:

# %%
my_query = {"$and": [{"text": {"$regex": re.compile("mcdonald’s", re.IGNORECASE)}}, 
                     {"search_word": "burger"}]}

cursor = twitter_info.find(my_query)

i=0

for x in cursor:
    i+=1
    print(x['text']+'\n'+'-----')
    
print('\n --> ' + str(i) + ' documents in total')
# Out:
# I hate my cravings when Mother Nature be in town. It’s always a double cheese burger from McDonald’s. I haven’t given in to these cravings since college. But right now?! It’s killing me 😭😭
# -----
#
#  --> 1 documents in total

# %%
my_query = {"$and": [{"text": {"$regex": re.compile("mcdonald’s", re.IGNORECASE)}}, 
                     {"search_word": "fries"}]}

cursor = twitter_info.find(my_query)

i=0

for x in cursor:
    i+=1
    print(x['text']+'\n'+'-----')
    
print('\n --> ' + str(i) + ' documents in total')
# Out:
# I love me some reheated McDonald’s French fries
# -----
# @MadScientistFF Wendy’s baconator
# McDonald’s fries
# Cotton candy blizzard
# -----
# Just ate a 20 piece and 2 large fries from McDonald’s. Will I die?
# -----
# McDonald’s fries n a blunt&gt;&gt;&gt; 😩😩😩
# -----
#
#  --> 4 documents in total

# %%
my_query = {"$and": [{"text": {"$regex": re.compile("mcdonald’s", re.IGNORECASE)}}, 
                     {"search_word": "cheese"}]}

cursor = twitter_info.find(my_query)

i=0

for x in cursor:
    i+=1
    print(x['text']+'\n'+'-----')
    
print('\n --> ' + str(i) + ' documents in total')
# Out:
# I hate my cravings when Mother Nature be in town. It’s always a double cheese burger from McDonald’s. I haven’t given in to these cravings since college. But right now?! It’s killing me 😭😭
# -----
#
#  --> 1 documents in total

# %% [markdown]
# Este tweet é repetido, mas aparece duas vezes no total de 31 - uma vez com a palavra "burger" e outra com a palavra "cheese".

# %% [markdown]
# **P3:** Esta repetição pode ser problemática?

# %%
my_query = {"$and": [{"text": {"$regex": re.compile("mcdonald’s", re.IGNORECASE)}}, 
                     {"search_word": "bacon"}]}

cursor = twitter_info.find(my_query)

i=0

for x in cursor:
    i+=1
    print(x['text']+'\n'+'-----')
    
print('\n --> ' + str(i) + ' documents in total')
# Out:
#  --> 0 documents in total

# %% [markdown]
# #### 6. Load data from the data_twitter collection into a dataframe

# %%
# select tweets posted on 2022-09-26 after 23:29

my_query = {"created_at": {"$gt": "2022-09-26T23:29:00.000Z"}}
            
cursor = twitter_info.find(my_query)

for x in cursor:
    print(x)
# Out:
# {'_id': ObjectId('6332ded8239d27df11bd2017'), 'created_at': '2022-09-26T23:29:55.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 1, 'quote_count': 0}, 'text': 'Factory reset your circadian rhythm 101:\nEat something super unhealthy and inflammatory at 9pm like pizza/instant noodles/burger with tons of store bought mayo.\nSleep when you pass out.\n\nTA-DAAA !!', 'id': '1574541810738659328', 'lang': 'en', 'search_word': 'burger'}
# {'_id': ObjectId('6332ded8239d27df11bd2018'), 'created_at': '2022-09-26T23:29:49.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0
_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}, 'lang': 'en', 'search_word': 'bacon'}

# %%
import pandas as pd

# %%
cursor = twitter_info.find(my_query)

list_cursor = list(cursor)

df = pd.DataFrame(list_cursor)

# %%
df.head()
# Out:
#                         _id                created_at  \
# 0  6332ded8239d27df11bd2017  2022-09-26T23:29:55.000Z
# 1  6332ded8239d27df11bd2018  2022-09-26T23:29:49.000Z
# 2  6332ded8239d27df11bd2019  2022-09-26T23:29:48.000Z
# 3  6332ded8239d27df11bd201a  2022-09-26T23:29:39.000Z
# 4  6332ded8239d27df11bd201b  2022-09-26T23:29:27.000Z
#
#                                       public_metrics  \
# 0  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 2  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 3  {'retweet_count': 7, 'reply_count': 137, 'like...
# 4  {'retweet_count': 0, 'reply_count': 2, 'like_c...
#
#                                                 text                   id  \
# 0  Factory reset your circadian rhythm 101:\nEat ...  1574541810738659328
# 1  @Buffpup_ Me looking at that burger like... ht...  1574541785900384256
# 2  @FearTheFloof As a fellow child of the 80s, I ...  1574541780405702670
# 3  Which 3 toppings are you adding to your Burger...  1574541743584088064
# 4  @Smollbrainarti2 @kawaii_blue368 You should al...  1574541692476174336
#
#   lang search_word
# 0   en      burger
# 1   en      burger
# 2   en      burger
# 3   en      burger
# 4   en      burger

# %%
df['retweets'] = df['public_metrics'].map(lambda x: x['retweet_count'])
df['replies'] = df['public_metrics'].map(lambda x: x['reply_count'])
df['likes'] = df['public_metrics'].map(lambda x: x['like_count'])
df['quotes'] = df['public_metrics'].map(lambda x: x['quote_count'])

df.drop('public_metrics', axis=1, inplace=True)

df.head()
# Out:
#                         _id                created_at  \
# 0  6332ded8239d27df11bd2017  2022-09-26T23:29:55.000Z
# 1  6332ded8239d27df11bd2018  2022-09-26T23:29:49.000Z
# 2  6332ded8239d27df11bd2019  2022-09-26T23:29:48.000Z
# 3  6332ded8239d27df11bd201a  2022-09-26T23:29:39.000Z
# 4  6332ded8239d27df11bd201b  2022-09-26T23:29:27.000Z
#
#                                                 text                   id  \
# 0  Factory reset your circadian rhythm 101:\nEat ...  1574541810738659328
# 1  @Buffpup_ Me looking at that burger like... ht...  1574541785900384256
# 2  @FearTheFloof As a fellow child of the 80s, I ...  1574541780405702670
# 3  Which 3 toppings are you adding to your Burger...  1574541743584088064
# 4  @Smollbrainarti2 @kawaii_blue368 You should al...  1574541692476174336
#
#   lang search_word  retweets  replies  likes  quotes
# 0   en      burger         0        0      1       0
# 1   en      burger         0        0      0       0
# 2   en      burger         0        0      1       0
# 3   en      burger         7      137     79      26
# 4   en      burger         0        2      3       0

# %% [markdown]
# #### 7. Check collections after running the .py script to extract keywords

# %%
db.list_collection_names()
# Out:
# ['data_twitter', 'client_info', 'kw_freq_weight']

# %% [markdown]
# #### 8. Select data from the kw_freq_weight collection

# %%
 kw_freq_weight = db['kw_freq_weight']

# %%
# keywords with term frequency

for doc in kw_freq_weight.find():
    print(doc)
# Out:
# {'_id': ObjectId('633eaf73c37500096947803b'), 'cheese': 728, 'burger': 276, 'bacon': 229, 'fries': 219, 'like': 150, 'mac': 80, 'chicken': 68, 'good': 65, 'eat': 58, 'get': 56, 'love': 53, '️': 53, 'cream': 49, 'go': 46, 'one': 45, '😂': 45, 'eating': 43, 'sandwich': 43, 'want': 42, 'grilled': 41, 'made': 40, 'got': 39, 'egg': 38, 'would
 9, 'sugar': 9, 'pumpkin': 9, 'bun': 9, 'large': 9, 'work': 9, 'fresh': 9, 'chopped': 9, 'though': 9, 'fish': 9, 'side': 9, 'thought': 9, 'ordered': 9, 'mayo': 9, 'tried': 9, 'gotta': 9, 'green': 9, 'tho': 9, 'whole': 9, 'impossible': 9, 'times': 9, 'pound': 9, 'apple': 9, 'mcdonalds': 9, 'cooking': 9, 'im': 9, 'nice': 9, 'extra': 8, 'anyone': 8, 'red': 8, 'oven': 8, 'boy': 8, 'turkey': 8, 'nasty': 8, 'double': 8, 'stop': 8, 'cake': 8, 'fat': 8, "he's": 8, 'instead': 8, 'high': 8, 'called': 8, 'hope': 8, '🥓': 8, '💛': 8, 'talking': 8, 'different': 8, 'pork': 8, 'cook': 8, 'cottage': 8, 'wild': 8, 'ok': 8, 'wine': 8, 'milk': 8, 'someone': 8, 'combo': 8, 'gets': 8, 'serving': 8, 'might': 8, 'smell': 8, 'feel': 8, 'noodles': 8, 'veggie': 8, '🔥': 8, 'peanut': 8, 'iced': 8, 'pasta': 8, 'fry': 8, 'goat': 7, 'everyone': 7, 'bits': 7, 'bro': 7, 'crackers': 7, 'cause': 7, 'weird': 7, 'black': 7, 'else': 7, 'working': 7, 'least': 7, 'game': 7, 'small': 7, 'daily': 7, 'baby': 7, 'craving': 7, 'start': 7, 'crazy': 7, 'thin': 7, 'bite': 7, "can't": 7, 'nuggets': 7, 'gave': 7, 'biscuit': 7, 'crust': 7, 'forgot': 7, 'second': 7, 'corn': 7, 'check': 7, 'bc': 7, 'quite': 7, 'dog': 7, 'cheeses': 7, 'vanil ...

# %%
# drop collection

kw_freq_weight.drop()

# %%
db.list_collection_names()
# Out:
# ['data_twitter', 'client_info']

# %% [markdown]
# We will now run the .py script to get the term weights.

# %%
db.list_collection_names()
# Out:
# ['kw_freq_weight', 'data_twitter', 'client_info']

# %%
kw_freq_weight = db['kw_freq_weight']

# %%
# keywords with term weights (textrank)
for doc in kw_freq_weight.find():
    print(doc)
# Out:
# {'_id': ObjectId('633eb01f6ea77c9738476ffb'), 'cheese': 23.596248039592187, 'bacon': 7.179627618338529, 'fries': 6.995001923096951, 'burger': 6.554524076328362, 'amp': 3.120674068204275, 'mac': 3.107978258661805, 'burger king': 2.8467188239304897, 'french fries': 2.131670943025498, 'good': 1.7690656865241219, 'swiss cheese': 1.494800986126786, 'dick cheese': 1.3379525322003034, 'kevin bacon': 1.2977106730213792, 'cream cheese': 1.2731744802612175, 'people': 1.205777587425598, 'chuck e. cheese': 1.2019863785355152, 'american cheese': 1.151556513707664, 'cheese pizza': 1.080499604057313, 'chicken': 1.027264346856799, 'bacon egg': 1.012400277354275, 'fries tonight': 0.9999999999999998, 'te amo burger king': 0.9999999999999998, 'taco fries tonight': 0.9999999999999998, 'cottage cheese legs': 0.9999999999999998, 'fuck cream cheese': 0.9999999999999998, 'emotional support cheese': 0.9999999999999998, 'goat cheese soup': 0.9999999999999998, 'cottage cheese': 0.9718798021643436, 'dinner': 0.9210045978517
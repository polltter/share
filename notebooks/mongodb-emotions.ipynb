# %% [markdown]
# # C-More

# %%
import pymongo

# %%
client = pymongo.MongoClient('mongodb://localhost:27017/')

# %%
db = client['rep_analysis_main']

# %%
db.list_collection_names()
# Out:
# ['sentiment_monthly_main',
#  'data_test',
#  'kw_freq_weight_monthly_test',
#  'kw_freq_weight_test',
#  'kw_freq_weight_annually_test',
#  'client_info',
#  'sentiment_monthly_test',
#  'kw_daily_main',
#  'kw_freq_weight_daily_test',
#  'sentiment_annually_test',
#  'sentiment_weekly_test',
#  'sentiment_weekly_main',
#  'data_twitter',
#  'sentiment_test',
#  'kw_yearly_main',
#  'sentiment_daily_test',
#  'sentiment_daily_main',
#  'kw_freq_weight_weekly_test',
#  'kw_weekly_main',
#  'sentiment_yearly_main',
#  'kw_monthly_main']

# %% [markdown]
# #### 1. Perform emotion analysis on a daily basis

# %% [markdown]
# We will run our emotion_analysis.py script manually to simulate this analysis on a daily basis.

# %%
db.list_collection_names()
# Out:
# ['sentiment_monthly_main',
#  'data_test',
#  'kw_freq_weight_monthly_test',
#  'kw_freq_weight_test',
#  'kw_freq_weight_annually_test',
#  'client_info',
#  'sentiment_monthly_test',
#  'kw_daily_main',
#  'kw_freq_weight_daily_test',
#  'emotions_test',
#  'sentiment_annually_test',
#  'sentiment_weekly_test',
#  'sentiment_weekly_main',
#  'data_twitter',
#  'sentiment_test',
#  'kw_yearly_main',
#  'sentiment_daily_test',
#  'sentiment_daily_main',
#  'kw_freq_weight_weekly_test',
#  'kw_weekly_main',
#  'sentiment_yearly_main',
#  'kw_monthly_main']

# %% [markdown]
# We have created a collection named emotions_test.

# %%
emotions_test = db['emotions_test']

# %%
for doc in emotions_test.find():
    print(doc)
# Out:
# {'_id': ObjectId('63494f409eaa308461b89983'), 'lang': 'en', 'created_at': '2022-10-14T11:59:47.000Z', 'text': '@lurk_burger Thank u for seeing my genius 🖤', 'edit_history_tweet_ids': ['1580891113715822592'], 'id': '1580891113715822592', 'search_word': 'burger', 'extracted_at': '2022-09-29', 'retweets': 0, 'replies': 0, 'likes': 0, 'quotes': 0, 'mood': [['INSPIRED', 0.22760355015964587], ['AMUSED', 0.1839351067999557], ['DONT_CARE', 0.13466523645560408], ['ANNOYED', 0.12191949284674691], ['HAPPY', 0.10458414755025659], ['SAD', 0.09921438943601268], ['ANGRY', 0.07082422857153911], ['AFRAID', 0.057253848180239084]], 'top1_mood': 'INSPIRED', 'top2_mood': 'AMUSED', 'top3_mood': 'DONT_CARE'}
# ...

# %%
emotions_test.count_documents({})
# Out:
# 98

# %% [markdown]
# We have analysed the emotions of our first 100 tweets (2022-09-29). Out of these 100 tweets, the analysis was successfully performed for 98 tweets.
#
# We will now run the script again, changing the extraction date for the following days.

# %%
emotions_test.count_documents({})
# Out:
# 2024

# %% [markdown]
# After running the script for all the available days, we get the results for all our tweets.

# %%
for doc in emotions_test.find():
    print(doc)
# Out:
# {'_id': ObjectId('63494f409eaa308461b89983'), 'lang': 'en', 'created_at': '2022-10-14T11:59:47.000Z', 'text': '@lurk_burger Thank u for seeing my genius 🖤', 'edit_history_tweet_ids': ['1580891113715822592'], 'id': '1580891113715822592', 'search_word': 'burger', 'extracted_at': '2022-09-29', 'retweets': 0, 'replies': 0, 'likes': 0, 'quotes': 0, 'mood': [['INSPIRED', 0.22760355015964587], ['AMUSED', 0.1839351067999557], ['DONT_CARE', 0.13466523645560408], ['ANNOYED', 0.12191949284674691], ['HAPPY', 0.10458414755025659], ['SAD', 0.09921438943601268], ['ANGRY', 0.07082422857153911], ['AFRAID', 0.057253848180239084]], 'top1_mood': 'INSPIRED', 'top2_mood': 'AMUSED', 'top3_mood': 'DONT_CARE'}
# ...

# %% [markdown]
# #### 2. Aggregate the emotion analysis results per day

# %% [markdown]
# We will use the emotions_test collection as our source of data.
#
# After running the emotion_analysis.py script for the daily aggregation ("2022-09-29"), we get:

# %%
#db["emotions_daily_main"].drop()

# %%
db.list_collection_names()
# Out:
# ['sentiment_monthly_main',
#  'data_test',
#  'kw_freq_weight_monthly_test',
#  'kw_freq_weight_test',
#  'kw_freq_weight_annually_test',
#  'client_info',
#  'sentiment_monthly_test',
#  'kw_daily_main',
#  'kw_freq_weight_daily_test',
#  'emotions_test',
#  'sentiment_annually_test',
#  'emotions_daily_main',
#  'sentiment_weekly_test',
#  'sentiment_weekly_main',
#  'data_twitter',
#  'emotions_yearly_main',
#  'sentiment_test',
#  'kw_yearly_main',
#  'sentiment_daily_test',
#  'sentiment_daily_main',
#  'emotions_monthly_main',
#  'emotions_weekly_main',
#  'kw_freq_weight_weekly_test',
#  'kw_weekly_main',
#  'sentiment_yearly_main',
#  'kw_monthly_main']

# %% [markdown]
# We have a new collection, emotions_daily_main.

# %%
emotions_daily_main = db['emotions_daily_main']

# %%
for doc in emotions_daily_main.find():
    print(doc)
# Out:
# {'_id': ObjectId('635bc92ab228f0210199f274'), 'extracted_at': '2022-09-29', 'year': '2022', 'month': '09', 'week_of_year': '39', 'n_tweets': 98, 'amused_count': 92, 'amused_percent': 0.94, 'afraid_count': 1, 'afraid_percent': 0.01, 'angry_count': 10, 'angry_percent': 0.1, 'annoyed_count': 11, 'annoyed_percent': 0.11, 'dontcare_count': 64, 'dontcare_percent': 0.65, 'happy_count': 13, 'happy_percent': 0.13, 'inspired_count': 90, 'inspired_percent': 0.92, 'sad_count': 13, 'sad_percent': 0.13}

# %% [markdown]
# After running the script for all the days we have available, we get the following result:

# %%
for doc in emotions_daily_main.find():
    print(doc)
# Out:
# {'_id': ObjectId('635bc92ab228f0210199f274'), 'extracted_at': '2022-09-29', 'year': '2022', 'month': '09', 'week_of_year': '39', 'n_tweets': 98, 'amused_count': 92, 'amused_percent': 0.94, 'afraid_count': 1, 'afraid_percent': 0.01, 'angry_count': 10, 'angry_percent': 0.1, 'annoyed_count': 11, 'annoyed_percent': 0.11, 'dontcare_count': 64, 'dontcare_percent': 0.65, 'happy_count': 13, 'happy_percent': 0.13, 'inspired_count': 90, 'inspired_percent': 0.92, 'sad_count': 13, 'sad_percent': 0.13}
# {'_id': ObjectId('635bc9f47814e2288bee6c75'), 'extracted_at': '2022-09-30', 'year': '2022', 'month': '09', 'week_of_year': '39', 'n_tweets': 98, 'amused_count': 96, 'amused_percent': 0.98, 'afraid_count': 2, 'afraid_percent': 0.02, 'angry_count': 10, 'angry_percent': 0.1, 'annoyed_count': 9, 'annoyed_percent': 0.09, 'dontcare_count': 63, 'dontcare_percent': 0.64, 'happy_count': 14, 'happy_percent': 0.14, 'inspired_count': 94, 'inspired_percent': 0.96, 'sad_count': 6, 'sad_percent': 0.06}
# ...

# %%
emotions_daily_main.count_documents({})
# Out:
# 21

# %% [markdown]
# #### 3. Aggregate the emotion analysis results per week

# %% [markdown]
# After running the emotion_analysis.py script for the weekly aggregation ("39"), we get:

# %%
#db["emotions_weekly_main"].drop()

# %%
db.list_collection_names()
# Out:
# ['sentiment_monthly_main',
#  'data_test',
#  'emotions_weekly_main',
#  'kw_freq_weight_monthly_test',
#  'kw_freq_weight_test',
#  'kw_freq_weight_annually_test',
#  'client_info',
#  'sentiment_monthly_test',
#  'kw_daily_main',
#  'kw_freq_weight_daily_test',
#  'emotions_test',
#  'sentiment_annually_test',
#  'emotions_daily_main',
#  'sentiment_weekly_test',
#  'sentiment_weekly_main',
#  'data_twitter',
#  'emotions_yearly_main',
#  'sentiment_test',
#  'kw_yearly_main',
#  'sentiment_daily_test',
#  'sentiment_daily_main',
#  'emotions_monthly_main',
#  'kw_freq_weight_weekly_test',
#  'kw_weekly_main',
#  'sentiment_yearly_main',
#  'kw_monthly_main']

# %% [markdown]
# We have a new collection, emotions_weekly_main.

# %%
emotions_weekly_main = db['emotions_weekly_main']

# %%
for doc in emotions_weekly_main.find():
    print(doc)
# Out:
# {'_id': {'year_week': ['2022', '39']}, 'total_amused_count': 283, 'total_afraid_count': 3, 'total_angry_count': 28, 'total_annoyed_count': 37, 'total_dontcare_count': 192, 'total_happy_count': 40, 'total_inspired_count': 274, 'total_sad_count': 25, 'total_n_tweets': 294, 'total_number_of_days': 3, 'amused_percent': 0.96, 'afraid_percent': 0.01, 'angry_percent': 0.1, 'annoyed_percent': 0.13, 'dontcare_percent': 0.65, 'happy_percent': 0.14, 'inspired_percent': 0.93, 'sad_percent': 0.09}

# %% [markdown]
# After running the script for all the weeks we have available, we get the following result:

# %%
for doc in emotions_weekly_main.find():
    print(doc)
# Out:
# {'_id': {'year_week': ['2022', '39']}, 'total_amused_count': 283, 'total_afraid_count': 3, 'total_angry_count': 28, 'total_annoyed_count': 37, 'total_dontcare_count': 192, 'total_happy_count': 40, 'total_inspired_count': 274, 'total_sad_count': 25, 'total_n_tweets': 294, 'total_number_of_days': 3, 'amused_percent': 0.96, 'afraid_percent': 0.01, 'angry_percent': 0.1, 'annoyed_percent': 0.13, 'dontcare_percent': 0.65, 'happy_percent': 0.14, 'inspired_percent': 0.93, 'sad_percent': 0.09}
# {'_id': {'year_week': ['2022', '40']}, 'total_amused_count': 667, 'total_afraid_count': 4, 'total_angry_count': 59, 'total_annoyed_count': 104, 'total_dontcare_count': 427, 'total_happy_count': 134, 'total_inspired_count': 614, 'total_sad_count': 46, 'total_n_tweets': 685, 'total_number_of_days': 7, 'amused_percent': 0.97, 'afraid_percent': 0.01, 'angry_percent': 0.09, 'annoyed_percent': 0.15, 'dontcare_percent': 0.62, 'happy_percent': 0.2, 'inspired_percent': 0.9, 'sad_percent': 0.07}
# ...

# %% [markdown]
# #### 4. Aggregate the emotion analysis results per month

# %% [markdown]
# After running the emotion_analysis.py script for the monthly aggregation ("09"), we get:

# %%
#db["emotions_monthly_main"].drop()

# %%
db.list_collection_names()
# Out:
# ['sentiment_monthly_main',
#  'data_test',
#  'emotions_weekly_main',
#  'kw_freq_weight_monthly_test',
#  'kw_freq_weight_test',
#  'kw_freq_weight_annually_test',
#  'client_info',
#  'sentiment_monthly_test',
#  'kw_daily_main',
#  'kw_freq_weight_daily_test',
#  'emotions_test',
#  'sentiment_annually_test',
#  'emotions_daily_main',
#  'sentiment_weekly_test',
#  'sentiment_weekly_main',
#  'data_twitter',
#  'emotions_yearly_main',
#  'sentiment_test',
#  'emotions_monthly_main',
#  'kw_yearly_main',
#  'sentiment_daily_test',
#  'sentiment_daily_main',
#  'kw_freq_weight_weekly_test',
#  'kw_weekly_main',
#  'sentiment_yearly_main',
#  'kw_monthly_main']

# %% [markdown]
# We have a new collection, emotions_monthly_main.

# %%
emotions_monthly_main = db['emotions_monthly_main']

# %%
for doc in emotions_monthly_main.find():
    print(doc)
# Out:
# {'_id': {'year_month': ['2022', '09']}, 'total_amused_count': 188, 'total_afraid_count': 3, 'total_angry_count': 20, 'total_annoyed_count': 20, 'total_dontcare_count': 127, 'total_happy_count': 27, 'total_inspired_count': 184, 'total_sad_count': 19, 'total_n_tweets': 196, 'total_number_of_days': 2, 'amused_percent': 0.96, 'afraid_percent': 0.02, 'angry_percent': 0.1, 'annoyed_percent': 0.1, 'dontcare_percent': 0.65, 'happy_percent': 0.14, 'inspired_percent': 0.94, 'sad_percent': 0.1, 'year': '2022'}

# %% [markdown]
# After running the script for all the months we have available, we get the following result:

# %%
for doc in emotions_monthly_main.find():
    print(doc)
# Out:
# {'_id': {'year_month': ['2022', '09']}, 'total_amused_count': 188, 'total_afraid_count': 3, 'total_angry_count': 20, 'total_annoyed_count': 20, 'total_dontcare_count': 127, 'total_happy_count': 27, 'total_inspired_count': 184, 'total_sad_count': 19, 'total_n_tweets': 196, 'total_number_of_days': 2, 'amused_percent': 0.96, 'afraid_percent': 0.02, 'angry_percent': 0.1, 'annoyed_percent': 0.1, 'dontcare_percent': 0.65, 'happy_percent': 0.14, 'inspired_percent': 0.94, 'sad_percent': 0.1, 'year': '2022'}
# ...

# %% [markdown]
# #### 5. Aggregate the emotion analysis results per year

# %% [markdown]
# After running the emotion_analysis.py script for the yearly aggregation ("2022"), we get:

# %%
#db["emotions_yearly_main"].drop()

# %%
db.list_collection_names()
# Out:
# ['sentiment_monthly_main',
#  'data_test',
#  'emotions_weekly_main',
#  'kw_freq_weight_monthly_test',
#  'kw_freq_weight_test',
#  'kw_freq_weight_annually_test',
#  'client_info',
#  'sentiment_monthly_test',
#  'kw_daily_main',
#  'kw_freq_weight_daily_test',
#  'emotions_test',
#  'sentiment_annually_test',
#  'emotions_daily_main',
#  'sentiment_weekly_test',
#  'sentiment_weekly_main',
#  'data_twitter',
#  'emotions_yearly_main',
#  'sentiment_test',
#  'emotions_monthly_main',
#  'kw_yearly_main',
#  'sentiment_daily_test',
#  'sentiment_daily_main',
#  'kw_freq_weight_weekly_test',
#  'kw_weekly_main',
#  'sentiment_yearly_main',
#  'kw_monthly_main']

# %% [markdown]
# We have a new collection, emotions_yearly_main.

# %%
emotions_yearly_main = db['emotions_yearly_main']

# %%
for doc in emotions_yearly_main.find():
    print(doc)
# Out:
# {'_id': {'year': '2022'}, 'total_amused_count': 1957, 'total_afraid_count': 21, 'total_angry_count': 191, 'total_annoyed_count': 297, 'total_dontcare_count': 1293, 'total_happy_count': 342, 'total_inspired_count': 1827, 'total_sad_count': 144, 'total_n_tweets': 2024, 'total_number_of_months': 2, 'amused_percent': 0.97, 'afraid_percent': 0.01, 'angry_percent': 0.09, 'annoyed_percent': 0.15, 'dontcare_percent': 0.64, 'happy_percent': 0.17, 'inspired_percent': 0.9, 'sad_percent': 0.07}

# %% [markdown]
# # C-More

# %%
import json
import pandas as pd

# %% [markdown]
# #### Load json data into a dataframe

# %%
list_json = []

with open('tweet_json_1day.txt') as file:
    for line in file:
        data = json.loads(line)
        list_json.append(data)

df = pd.DataFrame(list_json, columns = ['id', 'text', 'lang', 'created_at', 'public_metrics'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7153 entries, 0 to 7152
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              7153 non-null   object
#  1   text            7153 non-null   object
#  2   lang            7153 non-null   object
#  3   created_at      7153 non-null   object
#  4   public_metrics  7153 non-null   object
# dtypes: object(5)
# memory usage: 279.5+ KB

# %% [markdown]
# #### Select only tweets in English

# %%
df_en = df[df['lang'] == 'en'].copy()

# %%
df_en.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5377 entries, 0 to 7151
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              5377 non-null   object
#  1   text            5377 non-null   object
#  2   lang            5377 non-null   object
#  3   created_at      5377 non-null   object
#  4   public_metrics  5377 non-null   object
# dtypes: object(5)
# memory usage: 252.0+ KB

# %%
columns_to_remove = ['lang', 'created_at', 'public_metrics']

df_en.drop(columns_to_remove, axis=1, inplace=True)

# %%
df_en.reset_index(inplace=True, drop=True)

# %%
df_en.head()
# Out:
#                     id                                               text
# 0  1539397722595377152  @trashevrythng @hardevrythng @McDonalds and th...
# 1  1539397657571074049  @trashevrythng @hardevrythng @McDonalds respec...
# 2  1539397645625458688  @PeePosh2 @Scottschlittenh @sceley2011 @Joe_Ma...
# 3  1539397571013115904  @auauwra too bad im sending 8 mcdonalds large ...
# 4  1539397434715082754  @_idkjia Last time I went to McDonalds.  lol  ...

# %%
df_en.tail()
# Out:
#                        id                                               text
# 5372  1539035600451514375  if belos comes back we should just give him a ...
# 5373  1539035573263863808  we were at mcdonalds and suddenly 4 school bus...
# 5374  1539035538300207104  IM SORRY I TOLD U TO DRINK MCDONALDS SPRITE ht...
# 5375  1539035499242864641  Tough times @McDonalds inflation is shrinking ...
# 5376  1539035475352211456  @McDonalds It's literally raw so I am not sure...

# %% [markdown]
# #### Analyse emotions of tweets with the pipeline function

# %%
from transformers import pipeline

# %%
df_emo_hartmann = df_en.copy()

# %%
df_emo_hartmann.head()
# Out:
#                     id                                               text
# 0  1539397722595377152  @trashevrythng @hardevrythng @McDonalds and th...
# 1  1539397657571074049  @trashevrythng @hardevrythng @McDonalds respec...
# 2  1539397645625458688  @PeePosh2 @Scottschlittenh @sceley2011 @Joe_Ma...
# 3  1539397571013115904  @auauwra too bad im sending 8 mcdonalds large ...
# 4  1539397434715082754  @_idkjia Last time I went to McDonalds.  lol  ...

# %%
df_emo_hartmann.tail()
# Out:
#                        id                                               text
# 5372  1539035600451514375  if belos comes back we should just give him a ...
# 5373  1539035573263863808  we were at mcdonalds and suddenly 4 school bus...
# 5374  1539035538300207104  IM SORRY I TOLD U TO DRINK MCDONALDS SPRITE ht...
# 5375  1539035499242864641  Tough times @McDonalds inflation is shrinking ...
# 5376  1539035475352211456  @McDonalds It's literally raw so I am not sure...

# %%
# https://huggingface.co/j-hartmann/emotion-english-distilroberta-base

classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", top_k=1)
classifier("I love this!")
# Out:
# [{'label': 'joy', 'score': 0.9771687984466553}]

# %%
classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", top_k=3)
classifier("I love this!")
# Out:
# [{'label': 'joy', 'score': 0.9771687984466553},
#  {'label': 'surprise', 'score': 0.008528675884008408},
#  {'label': 'neutral', 'score': 0.005764578003436327}]

# %%
classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", top_k=7)
classifier("I love this!")
# Out:
# [{'label': 'joy', 'score': 0.9771687984466553},
#  {'label': 'surprise', 'score': 0.008528675884008408},
#  {'label': 'neutral', 'score': 0.005764578003436327},
#  {'label': 'anger', 'score': 0.004419777542352676},
#  {'label': 'sadness', 'score': 0.002092391485348344},
#  {'label': 'disgust', 'score': 0.0016119879437610507},
#  {'label': 'fear', 'score': 0.00041385198710486293}]

# %%
emotions = classifier(df_emo_hartmann['text'].tolist(), top_k=3) # top_k=3 to get the scores for the top-3 emotions

# %%
emotions
# Out:
# [[{'label': 'joy', 'score': 0.365884006023407},
#   {'label': 'neutral', 'score': 0.2650728225708008},
#   {'label': 'fear', 'score': 0.1775878220796585}],
#  [{'label': 'joy', 'score': 0.4457860291004181},
#   {'label': 'anger', 'score': 0.2831656336784363},
#   {'label': 'neutral', 'score': 0.16409169137477875}],
#  [{'label': 'fear', 'score': 0.5146477818489075},
#   {'label': 'anger', 'score': 0.2957209348678589},
#   {'label': 'sadness', 'score': 0.09062924981117249}],
#  [{'label': 'sadness', 'score': 0.957469642162323},
#   {'label': 'surprise', 'score': 0.018132803961634636},
#   {'label': 'neutral', 'score': 0.014415279030799866}],
#  [{'label': 'surprise', 'score': 0.6650456786155701},
#   {'label': 'joy', 'score': 0.13482117652893066},
#   {'label': 'neutral', 'score': 0.1345197558403015}],
#  [{'label': 'sadness', 'score': 0.574595034122467},
#   {'label': 'neutral', 'score': 0.13777540624141693},
#   {'label': 'surprise', 'score': 0.11814521998167038}],
#  [{'label': 'sadness', 'score': 0.6687462329864502},
#   {'label': 'surprise', 'score': 0.24005985260009766},
#   {'label': 'anger', 'score': 0.03966996446251869}],
#  [{'label': 'anger', 'score': 0.7031415104866028},
#   {'label': 'fear', 'score': 0.2832147181034088},
#   {'label': 'joy', 'score': 0.005234398413449526}],
#  [{'label': 'anger', 'score': 0.3670505881309509},
#   {'label': 'sadness', 'score': 0.33897900581359863},
#   {'label': 'surprise', 'score': 0.11087397485971451}],
#  [{'label': 'fear', 'score': 0.4757485091686249},
#   {'label': 'anger', 'score': 0.3003118336200714},
#   {'label': 'surprise', 'score': 0.06408647447824478}],
#  [{'label': 'neutral', 'score': 0.5531885623931885},
#   {'label': 'joy', 'score': 0.20288093388080597},
#   {'label': 'surprise', 'score': 0.17184816300868988}],
#  [{'label': 'surprise', 'score': 0.24566791951656342},
#   {'label': 'joy', 'score': 0.21242199838161469},
#   {'label': 'neutral', 'score': 0.19134506583213806}],
#  [{'label': 'fear', 'score': 0.619398295879364},
#   {'label': 'anger', 'score': 0.13584598898887634},
#   {'label': 'joy', 'score': 0.07733099162578583}],
#  [{'label': 'joy', 'score': 0.7414085865020752},
#   {'label': 'neutral', 'score': 0.11321686208248138},
#   {'label': 'surprise', 'score': 0.10984770208597183}],
#  [{'label': 'sadness', 'score': 0.45305106043815613},
#   {'label': 'neutral', 'score': 0.28115251660346985},
#   {'label': 'surprise', 'score': 0.19186000525951385}],
#  [{'label': 'neutral', 'score': 0.21183359622955322},
#   {'label': 'anger', 'score': 0.2050246000289917},
#   {'label': 'joy', 'score': 0.16589675843715668}],
#  [{'label': 'fear', 'score': 0.7254770398139954},
#   {'label': 'anger', 'score': 0.08392386138439178},
#   {'label': 'neutral', 'score': 0.06452390551567078}],
#  [{'label': 'joy', 'score': 0.5044453144073486},
#   {'label': 'neutral', 'score': 0.31518393754959106},
#   {'label': 'surprise', 'score': 0.1216978207230568}],
#  [{'label': 'joy', 'score': 0.8711884021759033},
#   {'label': 'surprise', 'score': 0.06568312644958496},
#   {'label': 'neutral', 'score': 0.05048925057053566}],
#  [{'label': 'joy', 'score': 0.8169217109680176},
#   {'label': 'neutral', 'score': 0.09622248262166977},
#   {'label': 'surprise', 'score': 0.07406006753444672}],
#  [{'label': 'neutral', 'score': 0.5039212107658386},
#   {'label': 'anger', 'score': 0.18092268705368042},
#   {'label': 'joy', 'score': 0.17223072052001953}],
#  [{'label': 'fear', 'score': 0.8890252709388733},
#   {'label': 'anger', 'score': 0.06800256669521332},
#   {'label': 'sadness', 'score': 0.02241121605038643}],
#  [{'label': 'sadness', 'score': 0.7677406668663025},
#   {'label': 'surprise', 'score': 0.13414551317691803},
#   {'label': 'neutral', 'score': 0.06981606781482697}],
#  [{'label': 'joy', 'score': 0.45996856689453125},
#   {'label': 'fear', 'score': 0.2690432071685791},
#   {'label': 'surprise', 'score': 0.10461507737636566}],
#  [{'label': 'fear', 'score': 0.892396092414856},
#   {'label': 'anger', 'score': 0.039409711956977844},
#   {'label': 'joy', 'score': 0.027392523363232613}],
#  [{'label': 'sadness', 'score': 0.8608936667442322},
#   {'label': 'surprise', 'score': 0.056321028620004654},
#   {'label': 'anger', 'score': 0.05446455627679825}],
#  [{'label': 'surprise', 'score': 0.8207132816314697},
#   {'label': 'joy', 'score': 0.07376015186309814},
#   {'label': 'fear', 'score': 0.0690246969461441}],
#  [{'label': 'surprise', 'score': 0.8985611200332642},
#   {'label': 'neutral', 'score': 0.059976495802402496},
#   {'label': 'anger', 'score': 0.013493926264345646}],
#  [{'label': 'joy', 'score': 0.8907185196876526},
#   {'label': 'surprise', 'score': 0.030053718015551567},
#   {'label': 'neutral', 'score': 0.028420129790902138}],
#  [{'label': 'anger', 'score': 0.9426337480545044},
#   {'label': 'fear', 'score': 0.04659713804721832},
#   {'label': 'sadness', 'score': 0.0030503927264362574}],
#  [{'label': 'neutral', 'score': 0.7981724143028259},
#   {'label': 'surprise', 'score': 0.10098157078027725},
#   {'label': 'disgust', 'score': 0.04985200986266136}],
#  [{'label': 'sadness', 'score': 0.9199951887130737},
#   {'label': 'anger', 'score': 0.03110036626458168},
#   {'label': 'surprise', 'score': 0.017959190532565117}],
#  [{'label': 'surprise', 'score': 0.8364381194114685},
#   {'label': 'joy', 'score': 0.08338575810194016},
#   {'label': 'neutral', 'score': 0.04903239384293556}],
#  [{'label': 'surprise', 'score': 0.4720461666584015},
#   {'label': 'neutral', 'score': 0.35822683572769165},
#   {'label': 'joy', 'score': 0.1300237476825714}],
#  [{'label': 'fear', 'score': 0.6391587853431702},
#   {'label': 'sadness', 'score': 0.16526556015014648},
#   {'label': 'anger', 'score': 0.1372823864221573}],
#  [{'label': 'joy', 'score': 0.9325736165046692},
#   {'label': 'anger', 'score': 0.0258951336145401},
#   {'label': 'fear', 'score': 0.015842460095882416}],
#  [{'label': 'surprise', 'score': 0.7738754153251648},
#   {'label': 'anger', 'score': 0.0736481323838234},
#   {'label': 'joy', 'score': 0.07274642586708069}],
#  [{'label': 'fear', 'score': 0.42840486764907837},
#   {'label': 'joy', 'score': 0.16489854454994202},
#   {'label': 'neutral', 'score': 0.12387890368700027}],
#  [{'label': 'disgust', 'score': 0.6007255911827087},
#   {'label': 'neutral', 'score': 0.1656232327222824},
#   {'label': 'anger', 'score': 0.13983511924743652}],
#  [{'label': 'anger', 'score': 0.7051716446876526},
#   {'label': 'fear', 'score': 0.24475876986980438},
#   {'label': 'joy', 'score': 0.01903098076581955}],
#  [{'label': 'fear', 'score': 0.45503345131874084},
#   {'label': 'sadness', 'score': 0.3788764476776123},
#   {'label': 'anger', 'score': 0.06160971149802208}],
#  [{'label': 'sadness', 'score': 0.7389048933982849},
#   {'label': 'surprise', 'score': 0.10586279630661011},
#   {'label': 'anger', 'score': 0.0919586792588234}],
#  [{'label': 'neutral', 'score': 0.785430908203125},
#   {'label': 'joy', 'score': 0.06929191201925278},
#   {'label': 'surprise', 'score': 0.06689070910215378}],
#  [{'label': 'neutral', 'score': 0.5695645213127136},
#   {'label': 'surprise', 'score': 0.20328330993652344},
#   {'label': 'joy', 'score': 0.1842203289270401}],
#  [{'label': 'joy', 'score': 0.8342107534408569},
#   {'label': 'surprise', 'score': 0.05183000862598419},
#   {'label': 'fear', 'score': 0.04182750731706619}],
#  [{'label': 'surprise', 'score': 0.44090017676353455},
#   {'label': 'fear', 'score': 0.19381164014339447},
#   {'label': 'sadness', 'score': 0.19047370553016663}],
#  [{'label': 'surprise', 'score': 0.7543741464614868},
#   {'label': 'neutral', 'score': 0.20155400037765503},
#   {'label': 'joy', 'score': 0.024950461462140083}],
#  [{'label': 'surprise', 'score': 0.6629459857940674},
#   {'label': 'neutral', 'score': 0.3055199980735779},
#   {'label': 'sadness', 'score': 0.011469664052128792}],
#  [{'label': 'anger', 'score': 0.9268319606781006},
#   {'label': 'neutral', 'score': 0.03926042467355728},
#   {'label': 'sadness', 'score': 0.01344060618430376}],
#  [{'label': 'anger', 'score': 0.9578185081481934},
#   {'label': 'fear', 'score': 0.02587221935391426},
#   {'label': 'neutral', 'score': 0.0067293387837708}],
#  [{'label': 'joy', 'score': 0.3540564179420471},
#   {'label': 'neutral', 'score': 0.3074970841407776},
#   {'label': 'surprise', 'score': 0.2825931906700134}],
#  [{'label': 'surprise', 'score': 0.435405433177948},
#   {'label': 'neutral', 'score': 0.3183026611804962},
#   {'label': 'joy', 'score': 0.1626254767179489}],
#  [{'label': 'surprise', 'score': 0.4410502314567566},
#   {'label': 'sadness', 'score': 0.2451391965150833},
#   {'label': 'anger', 'score': 0.18542686104774475}],
#  [{'label': 'fear', 'score': 0.6075568795204163},
#   {'label': 'anger', 'score': 0.14786335825920105},
#   {'label': 'joy', 'score': 0.09243284165859222}],
#  [{'label': 'fear', 'score': 0.8565284013748169},
#   {'label': 'anger', 'score': 0.044507529586553574},
#   {'label': 'joy', 'score': 0.03818053752183914}],
#  [{'label': 'disgust', 'score': 0.6189318895339966},
#   {'label': 'anger', 'score': 0.17246638238430023},
#   {'label': 'neutral', 'score': 0.13785232603549957}],
#  [{'label': 'neutral', 'score': 0.8753938674926758},
#   {'label': 'surprise', 'score': 0.09021411091089249},
#   {'label': 'anger', 'score': 0.012720377184450626}],
#  [{'label': 'anger', 'score': 0.8103381395339966},
#   {'label': 'fear', 'score': 0.12258253246545792},
#   {'label': 'sadness', 'score': 0.032196663320064545}],
#  [{'label': 'neutral', 'score': 0.4394475519657135},
#   {'label': 'joy', 'score': 0.3692607581615448},
#   {'label': 'surprise', 'score': 0.13082225620746613}],
#  [{'label': 'fear', 'score': 0.6722877621650696},
#   {'label': 'anger', 'score': 0.2593320608139038},
#   {'label': 'sadness', 'score': 0.038906246423721313}],
#  [{'label': 'anger', 'score': 0.9302367568016052},
#   {'label': 'fear', 'score': 0.024634500965476036},
#   {'label': 'disgust', 'score': 0.016640834510326385}],
#  [{'label': 'fear', 'score': 0.5988042950630188},
#   {'label': 'anger', 'score': 0.17650116980075836},
#   {'label': 'surprise', 'score': 0.1276330053806305}],
#  [{'label': 'anger', 'score': 0.9940505623817444},
#   {'label': 'sadness', 'score': 0.0022573652677237988},
#   {'label': 'neutral', 'score': 0.0009090243838727474}],
#  [{'label': 'surprise', 'score': 0.9737078547477722},
#   {'label': 'fear', 'score': 0.01305510476231575},
#   {'label': 'joy', 'score': 0.004599138628691435}],
#  [{'label': 'sadness', 'score': 0.9262229800224304},
#   {'label': 'anger', 'score': 0.05089074373245239},
#   {'label': 'surprise', 'score': 0.006852599326521158}],
#  [{'label': 'joy', 'score': 0.7502760887145996},
#   {'label': 'surprise', 'score': 0.1343921571969986},
#   {'label': 'neutral', 'score': 0.10020731389522552}],
#  [{'label': 'surprise', 'score': 0.9063148498535156},
#   {'label': 'fear', 'score': 0.04224411025643349},
#   {'label': 'joy', 'score': 0.026689501479268074}],
#  [{'label': 'surprise', 'score': 0.8198044300079346},
#   {'label': 'neutral', 'score': 0.13841913640499115},
#   {'label': 'joy', 'score': 0.021057909354567528}],
#  [{'label': 'sadness', 'score': 0.3571285605430603},
#   {'label': 'neutral', 'score': 0.2564931809902191},
#   {'label': 'anger', 'score': 0.18867133557796478}],
#  [{'label': 'fear', 'score': 0.7835754156112671},
#   {'label': 'anger', 'score': 0.06665119528770447},
#   {'label': 'neutral', 'score': 0.05277204141020775}],
#  [{'label': 'joy', 'score': 0.39951398968696594},
#   {'label': 'neutral', 'score': 0.35742342472076416},
#   {'label': 'surprise', 'score': 0.16427142918109894}],
#  [{'label': 'neutral', 'score': 0.5635512471199036},
#   {'label': 'surprise', 'score': 0.31051644682884216},
#   {'label': 'sadness', 'score': 0.09418221563100815}],
#  [{'label': 'fear', 'score': 0.33994555473327637},
#   {'label': 'neutral', 'score': 0.2771284580230713},
#   {'label': 'joy', 'score': 0.15103928744792938}],
#  [{'label': 'neutral', 'score': 0.3264918327331543},
#   {'label': 'joy', 'score': 0.22453151643276215},
#   {'label': 'anger', 'score': 0.15402202308177948}],
#  [{'label': 'neutral', 'score': 0.7486342191696167},
#   {'label': 'surprise', 'score': 0.18485583364963531},
#   {'label': 'joy', 'score': 0.028221260756254196}],
#  [{'label': 'anger', 'score': 0.5334938168525696},
#   {'label': 'neutral', 'score': 0.30804532766342163},
#   {'label': 'sadness', 'score': 0.07117680460214615}],
#  [{'label': 'sadness', 'score': 0.850775420665741},
#   {'label': 'surprise', 'score': 0.10368824005126953},
#   {'label': 'anger', 'score': 0.023141197860240936}],
#  [{'label': 'fear', 'score': 0.9211104512214661},
#   {'label': 'anger', 'score': 0.029026491567492485},
#   {'label': 'joy', 'score': 0.023803509771823883}],
#  [{'label': 'surprise', 'score': 0.7208135724067688},
#   {'label': 'anger', 'score': 0.13425949215888977},
#   {'label': 'neutral', 'score': 0.05940059572458267}],
#  [{'label': 'fear', 'score': 0.8250545859336853},
#   {'label': 'anger', 'score': 0.09334028512239456},
#   {'label': 'joy', 'score': 0.031084919348359108}],
#  [{'label': 'sadness', 'score': 0.49474668502807617},
#   {'label': 'fear', 'score': 0.16287551820278168},
#   {'label': 'surprise', 'score': 0.1448582261800766}],
#  [{'label': 'neutral', 'score': 0.3037058711051941},
#   {'label': 'fear', 'score': 0.27400797605514526},
#   {'label': 'joy', 'score': 0.24570047855377197}],
#  [{'label': 'surprise', 'score': 0.5630343556404114},
#   {'label': 'sadness', 'score': 0.17452795803546906},
#   {'label': 'anger', 'score': 0.1594802290201187}],
#  [{'label': 'fear', 'score': 0.891527533531189},
#   {'label': 'anger', 'score': 0.07465233653783798},
#   {'label': 'sadness', 'score': 0.011369788087904453}],
#  [{'label': 'joy', 'score': 0.7195643782615662},
#   {'label': 'anger', 'score': 0.1244540736079216},
#   {'label': 'neutral', 'score': 0.08218329399824142}],
#  [{'label': 'fear', 'score': 0.9734024405479431},
#   {'label': 'surprise', 'score': 0.01804337091743946},
#   {'label': 'sadness', 'score': 0.003268864704295993}],
#  [{'label': 'joy', 'score': 0.7138732671737671},
#   {'label': 'surprise', 'score': 0.18659217655658722},
#   {'label': 'anger', 'score': 0.032983724027872086}],
#  [{'label': 'joy', 'score': 0.7191799283027649},
#   {'label': 'neutral', 'score': 0.0874757394194603},
#   {'label': 'fear', 'score': 0.06190735101699829}],
#  [{'label': 'joy', 'score': 0.967290461063385},
#   {'label': 'surprise', 'score': 0.02029315009713173},
#   {'label': 'sadness', 'score': 0.004991455469280481}],
#  [{'label': 'fear', 'score': 0.7689819931983948},
#   {'label': 'anger', 'score': 0.18137520551681519},
#   {'label': 'joy', 'score': 0.02654525451362133}],
#  [{'label': 'surprise', 'score': 0.36814218759536743},
#   {'label': 'fear', 'score': 0.23405903577804565},
#   {'label': 'neutral', 'score': 0.22063982486724854}],
#  [{'label': 'neutral', 'score': 0.5314251184463501},
#   {'label': 'surprise', 'score': 0.3643631935119629},
#   {'label': 'anger', 'score': 0.041157789528369904}],
#  [{'label': 'surprise', 'score': 0.4992956817150116},
#   {'label': 'neutral', 'score': 0.3500796854496002},
#   {'label': 'joy', 'score': 0.06776107847690582}],
#  [{'label': 'surprise', 'score': 0.4554098844528198},
#   {'label': 'neutral', 'score': 0.20985360443592072},
#   {'label': 'sadness', 'score': 0.1916065514087677}],
#  [{'label': 'anger', 'score': 0.4424406886100769},
#   {'label': 'fear', 'score': 0.21114413440227509},
#   {'label': 'surprise', 'score': 0.12813575565814972}],
#  [{'label': 'fear', 'score': 0.8220390677452087},
#   {'label': 'anger', 'score': 0.14509467780590057},
#   {'label': 'sadness', 'score': 0.02043159306049347}],
#  [{'label': 'anger', 'score': 0.906028687953949},
#   {'label': 'joy', 'score': 0.03140847384929657},
#   {'label': 'surprise', 'score': 0.021919554099440575}],
#  [{'label': 'neutral', 'score': 0.6799708008766174},
#   {'label': 'surprise', 'score': 0.10301757603883743},
#   {'label': 'sadness', 'score': 0.06979399174451828}],
#  [{'label': 'fear', 'score': 0.4586178660392761},
#   {'label': 'anger', 'score': 0.25296086072921753},
#   {'label': 'joy', 'score': 0.21869488060474396}],
#  [{'label': 'surprise', 'score': 0.8354529142379761},
#   {'label': 'neutral', 'score': 0.089288130402565},
#   {'label': 'sadness', 'score': 0.04455076903104782}],
#  [{'label': 'anger', 'score': 0.5931268930435181},
#   {'label': 'sadness', 'score': 0.26080602407455444},
#   {'label': 'surprise', 'score': 0.05424743890762329}],
#  [{'label': 'anger', 'score': 0.9663711786270142},
#   {'label': 'fear', 'score': 0.013681975193321705},
#   {'label': 'sadness', 'score': 0.010542274452745914}],
#  [{'label': 'anger', 'score': 0.8060088753700256},
#   {'label': 'joy', 'score': 0.06338892877101898},
#   {'label': 'fear', 'score': 0.05772414058446884}],
#  [{'label': 'anger', 'score': 0.6240957379341125},
#   {'label': 'joy', 'score': 0.14103981852531433},
#   {'label': 'neutral', 'score': 0.13031113147735596}],
#  [{'label': 'disgust', 'score': 0.8821781277656555},
#   {'label': 'anger', 'score': 0.0760158896446228},
#   {'label': 'neutral', 'score': 0.023208683356642723}],
#  [{'label': 'fear', 'score': 0.8645988702774048},
#   {'label': 'anger', 'score': 0.06876253336668015},
#   {'label': 'joy', 'score': 0.02712012454867363}],
#  [{'label': 'neutral', 'score': 0.5561468601226807},
#   {'label': 'joy', 'score': 0.20419494807720184},
#   {'label': 'surprise', 'score': 0.16468971967697144}],
#  [{'label': 'disgust', 'score': 0.6566700339317322},
#   {'label': 'neutral', 'score': 0.20020943880081177},
#   {'label': 'fear', 'score': 0.06272877007722855}],
#  [{'label': 'fear', 'score': 0.6296421885490417},
#   {'label': 'neutral', 'score': 0.1140298843383789},
#   {'label': 'surprise', 'score': 0.10844849050045013}],
#  [{'label': 'joy', 'score': 0.7366127371788025},
#   {'label': 'neutral', 'score': 0.1498301774263382},
#   {'label': 'surprise', 'score': 0.08177740126848221}],
#  [{'label': 'surprise', 'score': 0.6016697287559509},
#   {'label': 'sadness', 'score': 0.33722588419914246},
#   {'label': 'neutral', 'score': 0.02688881754875183}],
#  [{'label': 'anger', 'score': 0.7069850564002991},
#   {'label': 'surprise', 'score': 0.1335425227880478},
#   {'label': 'sadness', 'score': 0.07687599211931229}],
#  [{'label': 'neutral', 'score': 0.3992409408092499},
#   {'label': 'joy', 'score': 0.3591741621494293},
#   {'label': 'surprise', 'score': 0.17466750741004944}],
#  [{'label': 'surprise', 'score': 0.5179552435874939},
#   {'label': 'anger', 'score': 0.18932239711284637},
#   {'label': 'sadness', 'score': 0.1770240068435669}],
#  [{'label': 'sadness', 'score': 0.9734222292900085},
#   {'label': 'anger', 'score': 0.012782244943082333},
#   {'label': 'joy', 'score': 0.004101173020899296}],
#  [{'label': 'anger', 'score': 0.5763962864875793},
#   {'label': 'surprise', 'score': 0.15702122449874878},
#   {'label': 'neutral', 'score': 0.13222406804561615}],
#  [{'label': 'anger', 'score': 0.7175894379615784},
#   {'label': 'sadness', 'score': 0.199215367436409},
#   {'label': 'joy', 'score': 0.04450418800115585}],
#  [{'label': 'joy', 'score': 0.3436325490474701},
#   {'label': 'surprise', 'score': 0.22285524010658264},
#   {'label': 'neutral', 'score': 0.17063309252262115}],
#  [{'label': 'fear', 'score': 0.8361373543739319},
#   {'label': 'anger', 'score': 0.055940914899110794},
#   {'label': 'joy', 'score': 0.045596975833177567}],
#  [{'label': 'neutral', 'score': 0.43718084692955017},
#   {'label': 'surprise', 'score': 0.25889334082603455},
#   {'label': 'joy', 'score': 0.18870842456817627}],
#  [{'label': 'surprise', 'score': 0.634224534034729},
#   {'label': 'joy', 'score': 0.132083460688591},
#   {'label': 'neutral', 'score': 0.1207418367266655}],
#  [{'label': 'joy', 'score': 0.5592843890190125},
#   {'label': 'neutral', 'score': 0.3327690660953522},
#   {'label': 'sadness', 'score': 0.05560699477791786}],
#  [{'label': 'fear', 'score': 0.8017967939376831},
#   {'label': 'sadness', 'score': 0.04984181746840477},
#   {'label': 'anger', 'score': 0.04721524566411972}],
#  [{'label': 'anger', 'score': 0.4439786374568939},
#   {'label': 'fear', 'score': 0.3699386417865753},
#   {'label': 'sadness', 'score': 0.09876669943332672}],
#  [{'label': 'anger', 'score': 0.6968967914581299},
#   {'label': 'fear', 'score': 0.24042750895023346},
#   {'label': 'surprise', 'score': 0.025099052116274834}],
#  [{'label': 'neutral', 'score': 0.5305108428001404},
#   {'label': 'surprise', 'score': 0.3564741015434265},
#   {'label': 'sadness', 'score': 0.051754195243120193}],
#  [{'label': 'anger', 'score': 0.9100356698036194},
#   {'label': 'sadness', 'score': 0.06275351345539093},
#   {'label': 'surprise', 'score': 0.008145025931298733}],
#  [{'label': 'sadness', 'score': 0.6688268184661865},
#   {'label': 'neutral', 'score': 0.1707276850938797},
#   {'label': 'surprise', 'score': 0.09624844044446945}],
#  [{'label': 'fear', 'score': 0.7326344847679138},
#   {'label': 'anger', 'score': 0.09124281257390976},
#   {'label': 'joy', 'score': 0.06976558268070221}],
#  [{'label': 'fear', 'score': 0.8086013197898865},
#   {'label': 'anger', 'score': 0.05809955298900604},
#   {'label': 'joy', 'score': 0.053335148841142654}],
#  [{'label': 'joy', 'score': 0.862792432308197},
#   {'label': 'surprise', 'score': 0.07203225791454315},
#   {'label': 'neutral', 'score': 0.05248506739735603}],
#  [{'label': 'joy', 'score': 0.9460026025772095},
#   {'label': 'neutral', 'score': 0.03266724571585655},
#   {'label': 'fear', 'score': 0.006555918604135513}],
#  [{'label': 'fear', 'score': 0.3686862885951996},
#   {'label': 'anger', 'score': 0.29191574454307556},
#   {'label': 'surprise', 'score': 0.25164151191711426}],
#  [{'label': 'anger', 'score': 0.8576750755310059},
#   {'label': 'disgust', 'score': 0.09458337724208832},
#   {'label': 'sadness', 'score': 0.018863117322325706}],
#  [{'label': 'anger', 'score': 0.9214648604393005},
#   {'label': 'fear', 'score': 0.03904493898153305},
#   {'label': 'sadness', 'score': 0.02908608689904213}],
#  [{'label': 'fear', 'score': 0.8111398816108704},
#   {'label': 'anger', 'score': 0.09711603075265884},
#   {'label': 'surprise', 'score': 0.04205116257071495}],
#  [{'label': 'sadness', 'score': 0.9462559223175049},
#   {'label': 'surprise', 'score': 0.016475537791848183},
#   {'label': 'neutral', 'score': 0.011925038881599903}],
#  [{'label': 'sadness', 'score': 0.8447124361991882},
#   {'label': 'surprise', 'score': 0.08309730142354965},
#   {'label': 'joy', 'score': 0.0403202623128891}],
#  [{'label': 'surprise', 'score': 0.5468438267707825},
#   {'label': 'neutral', 'score': 0.23939469456672668},
#   {'label': 'joy', 'score': 0.1942906528711319}],
#  [{'label': 'neutral', 'score': 0.5420515537261963},
#   {'label': 'sadness', 'score': 0.16871331632137299},
#   {'label': 'surprise', 'score': 0.11572114378213882}],
#  [{'label': 'neutral', 'score': 0.4239236116409302},
#   {'label': 'surprise', 'score': 0.3207450807094574},
#   {'label': 'sadness', 'score': 0.09766214340925217}],
#  [{'label': 'neutral', 'score': 0.3016660511493683},
#   {'label': 'surprise', 'score': 0.26426807045936584},
#   {'label': 'sadness', 'score': 0.2272847294807434}],
#  [{'label': 'neutral', 'score': 0.45569324493408203},
#   {'label': 'surprise', 'score': 0.39607733488082886},
#   {'label': 'joy', 'score': 0.08791579306125641}],
#  [{'label': 'joy', 'score': 0.7164667844772339},
#   {'label': 'fear', 'score': 0.23215781152248383},
#   {'label': 'anger', 'score': 0.02669183909893036}],
#  [{'label': 'surprise', 'score': 0.3143845200538635},
#   {'label': 'joy', 'score': 0.23273880779743195},
#   {'label': 'neutral', 'score': 0.21597859263420105}],
#  [{'label': 'fear', 'score': 0.9731010794639587},
#   {'label': 'anger', 'score': 0.010780613869428635},
#   {'label': 'sadness', 'score': 0.0062430365942418575}],
#  [{'label': 'surprise', 'score': 0.5304197669029236},
#   {'label': 'neutral', 'score': 0.27512243390083313},
#   {'label': 'anger', 'score': 0.0760435238480568}],
#  [{'label': 'sadness', 'score': 0.8555912971496582},
#   {'label': 'anger', 'score': 0.07034587115049362},
#   {'label': 'surprise', 'score': 0.0289588775485754}],
#  [{'label': 'neutral', 'score': 0.6494491100311279},
#   {'label': 'surprise', 'score': 0.18916256725788116},
#   {'label': 'sadness', 'score': 0.08641967177391052}],
#  [{'label': 'fear', 'score': 0.6346560120582581},
#   {'label': 'sadness', 'score': 0.2487279176712036},
#   {'label': 'anger', 'score': 0.08025714755058289}],
#  [{'label': 'surprise', 'score': 0.8719422221183777},
#   {'label': 'neutral', 'score': 0.09888624399900436},
#   {'label': 'sadness', 'score': 0.01004883088171482}],
#  [{'label': 'fear', 'score': 0.3430822789669037},
#   {'label': 'joy', 'score': 0.25678542256355286},
#   {'label': 'anger', 'score': 0.14415135979652405}],
#  [{'label': 'surprise', 'score': 0.32752659916877747},
#   {'label': 'neutral', 'score': 0.16729317605495453},
#   {'label': 'anger', 'score': 0.15283988416194916}],
#  [{'label': 'surprise', 'score': 0.5521659851074219},
#   {'label': 'sadness', 'score': 0.2995906174182892},
#   {'label': 'disgust', 'score': 0.06352818012237549}],
#  [{'label': 'neutral', 'score': 0.7695522308349609},
#   {'label': 'surprise', 'score': 0.09520255774259567},
#   {'label': 'disgust', 'score': 0.06409445405006409}],
#  [{'label': 'sadness', 'score': 0.563359260559082},
#   {'label': 'anger', 'score': 0.3653883934020996},
#   {'label': 'neutral', 'score': 0.024815918877720833}],
#  [{'label': 'joy', 'score': 0.8783814907073975},
#   {'label': 'surprise', 'score': 0.06355474889278412},
#   {'label': 'neutral', 'score': 0.04675700515508652}],
#  [{'label': 'surprise', 'score': 0.32630184292793274},
#   {'label': 'sadness', 'score': 0.23474310338497162},
#   {'label': 'fear', 'score': 0.1335870772600174}],
#  [{'label': 'joy', 'score': 0.5997974872589111},
#   {'label': 'neutral', 'score': 0.28972145915031433},
#   {'label': 'surprise', 'score': 0.07240619510412216}],
#  [{'label': 'surprise', 'score': 0.6070327758789062},
#   {'label': 'sadness', 'score': 0.1889767348766327},
#   {'label': 'anger', 'score': 0.1429063081741333}],
#  [{'label': 'fear', 'score': 0.5002015233039856},
#   {'label': 'joy', 'score': 0.20925500988960266},
#   {'label': 'anger', 'score': 0.15199047327041626}],
#  [{'label': 'anger', 'score': 0.857665479183197},
#   {'label': 'sadness', 'score': 0.07956325262784958},
#   {'label': 'fear', 'score': 0.02932163141667843}],
#  [{'label': 'anger', 'score': 0.6229540109634399},
#   {'label': 'neutral', 'score': 0.19155395030975342},
#   {'label': 'disgust', 'score': 0.09377235919237137}],
#  [{'label': 'sadness', 'score': 0.4293667674064636},
#   {'label': 'neutral', 'score': 0.25088179111480713},
#   {'label': 'surprise', 'score': 0.174525648355484}],
#  [{'label': 'sadness', 'score': 0.9591321349143982},
#   {'label': 'neutral', 'score': 0.018064111471176147},
#   {'label': 'joy', 'score': 0.00960774440318346}],
#  [{'label': 'surprise', 'score': 0.696898877620697},
#   {'label': 'neutral', 'score': 0.15286770462989807},
#   {'label': 'joy', 'score': 0.08895420283079147}],
#  [{'label': 'fear', 'score': 0.7894154191017151},
#   {'label': 'anger', 'score': 0.07087314128875732},
#   {'label': 'joy', 'score': 0.05855511501431465}],
#  [{'label': 'joy', 'score': 0.5305671691894531},
#   {'label': 'fear', 'score': 0.15087541937828064},
#   {'label': 'surprise', 'score': 0.13327421247959137}],
#  [{'label': 'neutral', 'score': 0.6431930661201477},
#   {'label': 'joy', 'score': 0.19572561979293823},
#   {'label': 'surprise', 'score': 0.1384556144475937}],
#  [{'label': 'surprise', 'score': 0.5427079200744629},
#   {'label': 'sadness', 'score': 0.3134210407733917},
#   {'label': 'neutral', 'score': 0.08861172944307327}],
#  [{'label': 'neutral', 'score': 0.2736798822879791},
#   {'label': 'joy', 'score': 0.25491926074028015},
#   {'label': 'surprise', 'score': 0.18076123297214508}],
#  [{'label': 'sadness', 'score': 0.838800311088562},
#   {'label': 'fear', 'score': 0.0765213668346405},
#   {'label': 'joy', 'score': 0.03210563585162163}],
#  [{'label': 'fear', 'score': 0.9256664514541626},
#   {'label': 'anger', 'score': 0.04495830088853836},
#   {'label': 'joy', 'score': 0.01633451133966446}],
#  [{'label': 'surprise', 'score': 0.9566238522529602},
#   {'label': 'neutral', 'score': 0.020129935815930367},
#   {'label': 'anger', 'score': 0.006962573621422052}],
#  [{'label': 'neutral', 'score': 0.3941117525100708},
#   {'label': 'surprise', 'score': 0.21901622414588928},
#   {'label': 'joy', 'score': 0.19128048419952393}],
#  [{'label': 'neutral', 'score': 0.5391764044761658},
#   {'label': 'joy', 'score': 0.2254226803779602},
#   {'label': 'surprise', 'score': 0.18347571790218353}],
#  [{'label': 'surprise', 'score': 0.36781564354896545},
#   {'label': 'joy', 'score': 0.27182188630104065},
#   {'label': 'neutral', 'score': 0.16864316165447235}],
#  [{'label': 'fear', 'score': 0.7543475031852722},
#   {'label': 'anger', 'score': 0.07389183342456818},
#   {'label': 'joy', 'score': 0.0649147480726242}],
#  [{'label': 'neutral', 'score': 0.4631415605545044},
#   {'label': 'surprise', 'score': 0.2744687795639038},
#   {'label': 'joy', 'score': 0.22881954908370972}],
#  [{'label': 'anger', 'score': 0.41272082924842834},
#   {'label': 'fear', 'score': 0.40316757559776306},
#   {'label': 'sadness', 'score': 0.09583206474781036}],
#  [{'label': 'neutral', 'score': 0.643354594707489},
#   {'label': 'surprise', 'score': 0.15852157771587372},
#   {'label': 'joy', 'score': 0.13740234076976776}],
#  [{'label': 'surprise', 'score': 0.5474653244018555},
#   {'label': 'sadness', 'score': 0.3593907356262207},
#   {'label': 'joy', 'score': 0.0507650300860405}],
#  [{'label': 'surprise', 'score': 0.3835941255092621},
#   {'label': 'joy', 'score': 0.2752695083618164},
#   {'label': 'sadness', 'score': 0.15838384628295898}],
#  [{'label': 'neutral', 'score': 0.43939483165740967},
#   {'label': 'surprise', 'score': 0.3132244646549225},
#   {'label': 'fear', 'score': 0.09787524491548538}],
#  [{'label': 'neutral', 'score': 0.4725717604160309},
#   {'label': 'sadness', 'score': 0.32835620641708374},
#   {'label': 'surprise', 'score': 0.10017726570367813}],
#  [{'label': 'fear', 'score': 0.9161946773529053},
#   {'label': 'anger', 'score': 0.054616495966911316},
#   {'label': 'joy', 'score': 0.013646717183291912}],
#  [{'label': 'surprise', 'score': 0.7769734859466553},
#   {'label': 'neutral', 'score': 0.1089031770825386},
#   {'label': 'joy', 'score': 0.05366724357008934}],
#  [{'label': 'sadness', 'score': 0.4099656045436859},
#   {'label': 'neutral', 'score': 0.3299964368343353},
#   {'label': 'surprise', 'score': 0.14940789341926575}],
#  [{'label': 'neutral', 'score': 0.565265417098999},
#   {'label': 'joy', 'score': 0.23990009725093842},
#   {'label': 'anger', 'score': 0.07332827895879745}],
#  [{'label': 'neutral', 'score': 0.46199384331703186},
#   {'label': 'surprise', 'score': 0.2076210230588913},
#   {'label': 'joy', 'score': 0.1849120855331421}],
#  [{'label': 'sadness', 'score': 0.7945140600204468},
#   {'label': 'neutral', 'score': 0.09747783094644547},
#   {'label': 'surprise', 'score': 0.09511003643274307}],
#  [{'label': 'anger', 'score': 0.756024181842804},
#   {'label': 'fear', 'score': 0.12092409282922745},
#   {'label': 'sadness', 'score': 0.059026625007390976}],
#  [{'label': 'neutral', 'score': 0.37532100081443787},
#   {'label': 'surprise', 'score': 0.31528428196907043},
#   {'label': 'joy', 'score': 0.19503697752952576}],
#  [{'label': 'joy', 'score': 0.52968829870224},
#   {'label': 'neutral', 'score': 0.25768741965293884},
#   {'label': 'surprise', 'score': 0.18146932125091553}],
#  [{'label': 'neutral', 'score': 0.7080656886100769},
#   {'label': 'surprise', 'score': 0.12596537172794342},
#   {'label': 'joy', 'score': 0.09342238306999207}],
#  [{'label': 'fear', 'score': 0.685123085975647},
#   {'label': 'anger', 'score': 0.130082905292511},
#   {'label': 'joy', 'score': 0.06607998162508011}],
#  [{'label': 'joy', 'score': 0.865247905254364},
#   {'label': 'neutral', 'score': 0.045443758368492126},
#   {'label': 'surprise', 'score': 0.0380256287753582}],
#  [{'label': 'neutral', 'score': 0.47528257966041565},
#   {'label': 'joy', 'score': 0.21005922555923462},
#   {'label': 'surprise', 'score': 0.16788427531719208}],
#  [{'label': 'neutral', 'score': 0.6482603549957275},
#   {'label': 'surprise', 'score': 0.17847377061843872},
#   {'label': 'sadness', 'score': 0.06420817226171494}],
#  [{'label': 'neutral', 'score': 0.93213951587677},
#   {'label': 'surprise', 'score': 0.04103199765086174},
#   {'label': 'sadness', 'score': 0.00919957086443901}],
#  [{'label': 'neutral', 'score': 0.4950549900531769},
#   {'label': 'surprise', 'score': 0.3202715218067169},
#   {'label': 'sadness', 'score': 0.16550523042678833}],
#  [{'label': 'joy', 'score': 0.4753114879131317},
#   {'label': 'neutral', 'score': 0.45773667097091675},
#   {'label': 'surprise', 'score': 0.036873240023851395}],
#  [{'label': 'anger', 'score': 0.23634424805641174},
#   {'label': 'fear', 'score': 0.22719059884548187},
#   {'label': 'surprise', 'score': 0.20291189849376678}],
#  [{'label': 'anger', 'score': 0.5397359132766724},
#   {'label': 'fear', 'score': 0.4316539764404297},
#   {'label': 'surprise', 'score': 0.0121186887845397}],
#  [{'label': 'sadness', 'score': 0.9283920526504517},
#   {'label': 'surprise', 'score': 0.030380992218852043},
#   {'label': 'neutral', 'score': 0.017772527411580086}],
#  [{'label': 'sadness', 'score': 0.6118608713150024},
#   {'label': 'surprise', 'score': 0.19687655568122864},
#   {'label': 'anger', 'score': 0.08473578095436096}],
#  [{'label': 'neutral', 'score': 0.8381269574165344},
#   {'label': 'joy', 'score': 0.11492083966732025},
#   {'label': 'sadness', 'score': 0.019740235060453415}],
#  [{'label': 'joy', 'score': 0.47850674390792847},
#   {'label': 'fear', 'score': 0.19941087067127228},
#   {'label': 'anger', 'score': 0.19524748623371124}],
#  [{'label': 'surprise', 'score': 0.46942654252052307},
#   {'label': 'neutral', 'score': 0.4037596881389618},
#   {'label': 'joy', 'score': 0.07087244093418121}],
#  [{'label': 'sadness', 'score': 0.38239219784736633},
#   {'label': 'anger', 'score': 0.3569071292877197},
#   {'label': 'surprise', 'score': 0.11563815921545029}],
#  [{'label': 'fear', 'score': 0.8579199910163879},
#   {'label': 'anger', 'score': 0.052396129816770554},
#   {'label': 'joy', 'score': 0.039459265768527985}],
#  [{'label': 'joy', 'score': 0.905035674571991},
#   {'label': 'surprise', 'score': 0.06031060963869095},
#   {'label': 'neutral', 'score': 0.02306256629526615}],
#  [{'label': 'joy', 'score': 0.8273859620094299},
#   {'label': 'surprise', 'score': 0.08256388455629349},
#   {'label': 'sadness', 'score': 0.04819657653570175}],
#  [{'label': 'joy', 'score': 0.9790497422218323},
#   {'label': 'surprise', 'score': 0.010025090537965298},
#   {'label': 'neutral', 'score': 0.0051288604736328125}],
#  [{'label': 'joy', 'score': 0.4275170564651489},
#   {'label': 'surprise', 'score': 0.34650281071662903},
#   {'label': 'neutral', 'score': 0.1952601671218872}],
#  [{'label': 'neutral', 'score': 0.5326295495033264},
#   {'label': 'surprise', 'score': 0.3653298318386078},
#   {'label': 'joy', 'score': 0.05429008975625038}],
#  [{'label': 'neutral', 'score': 0.9084588289260864},
#   {'label': 'surprise', 'score': 0.0619700625538826},
#   {'label': 'sadness', 'score': 0.01570851542055607}],
#  [{'label': 'anger', 'score': 0.9282439351081848},
#   {'label': 'disgust', 'score': 0.041099872440099716},
#   {'label': 'neutral', 'score': 0.01777047850191593}],
#  [{'label': 'neutral', 'score': 0.5981848239898682},
#   {'label': 'surprise', 'score': 0.27677392959594727},
#   {'label': 'joy', 'score': 0.06751734763383865}],
#  [{'label': 'surprise', 'score': 0.5726638436317444},
#   {'label': 'fear', 'score': 0.1380431354045868},
#   {'label': 'joy', 'score': 0.08307886868715286}],
#  [{'label': 'neutral', 'score': 0.4192335605621338},
#   {'label': 'disgust', 'score': 0.3377701938152313},
#   {'label': 'sadness', 'score': 0.1492622196674347}],
#  [{'label': 'surprise', 'score': 0.4364141523838043},
#   {'label': 'fear', 'score': 0.277088463306427},
#   {'label': 'joy', 'score': 0.1434122622013092}],
#  [{'label': 'surprise', 'score': 0.8133124709129333},
#   {'label': 'sadness', 'score': 0.11947702616453171},
#   {'label': 'neutral', 'score': 0.031036701053380966}],
#  [{'label': 'neutral', 'score': 0.8600675463676453},
#   {'label': 'joy', 'score': 0.06821076571941376},
#   {'label': 'surprise', 'score': 0.04446225240826607}],
#  [{'label': 'surprise', 'score': 0.6412057876586914},
#   {'label': 'neutral', 'score': 0.1537075787782669},
#   {'label': 'sadness', 'score': 0.11944952607154846}],
#  [{'label': 'surprise', 'score': 0.524758517742157},
#   {'label': 'neutral', 'score': 0.35675179958343506},
#   {'label': 'sadness', 'score': 0.0740085169672966}],
#  [{'label': 'fear', 'score': 0.729243814945221},
#   {'label': 'neutral', 'score': 0.09922301024198532},
#   {'label': 'anger', 'score': 0.09230112284421921}],
#  [{'label': 'fear', 'score': 0.7978692054748535},
#   {'label': 'anger', 'score': 0.060020238161087036},
#   {'label': 'joy', 'score': 0.052176620811223984}],
#  [{'label': 'neutral', 'score': 0.8217828273773193},
#   {'label': 'sadness', 'score': 0.09674572944641113},
#   {'label': 'surprise', 'score': 0.058928243815898895}],
#  [{'label': 'surprise', 'score': 0.49264538288116455},
#   {'label': 'neutral', 'score': 0.440703809261322},
#   {'label': 'fear', 'score': 0.020832616835832596}],
#  [{'label': 'fear', 'score': 0.8050059676170349},
#   {'label': 'anger', 'score': 0.07558610290288925},
#   {'label': 'joy', 'score': 0.04282855987548828}],
#  [{'label': 'fear', 'score': 0.8662973046302795},
#   {'label': 'anger', 'score': 0.04213970527052879},
#   {'label': 'joy', 'score': 0.03715073689818382}],
#  [{'label': 'joy', 'score': 0.8782448768615723},
#   {'label': 'surprise', 'score': 0.05987570434808731},
#   {'label': 'neutral', 'score': 0.0495627336204052}],
#  [{'label': 'neutral', 'score': 0.604885995388031},
#   {'label': 'sadness', 'score': 0.2985493540763855},
#   {'label': 'surprise', 'score': 0.05813411623239517}],
#  [{'label': 'joy', 'score': 0.45276933908462524},
#   {'label': 'fear', 'score': 0.1556759476661682},
#   {'label': 'surprise', 'score': 0.15428394079208374}],
#  [{'label': 'joy', 'score': 0.7129508256912231},
#   {'label': 'fear', 'score': 0.1027565449476242},
#   {'label': 'sadness', 'score': 0.07918603718280792}],
#  [{'label': 'neutral', 'score': 0.36412692070007324},
#   {'label': 'joy', 'score': 0.22789283096790314},
#   {'label': 'surprise', 'score': 0.21134509146213531}],
#  [{'label': 'joy', 'score': 0.593382716178894},
#   {'label': 'sadness', 'score': 0.1712121218442917},
#   {'label': 'surprise', 'score': 0.10174497216939926}],
#  [{'label': 'surprise', 'score': 0.36578062176704407},
#   {'label': 'neutral', 'score': 0.264570951461792},
#   {'label': 'joy', 'score': 0.14874383807182312}],
#  [{'label': 'neutral', 'score': 0.736859142780304},
#   {'label': 'surprise', 'score': 0.17950980365276337},
#   {'label': 'joy', 'score': 0.03783022612333298}],
#  [{'label': 'joy', 'score': 0.6073139905929565},
#   {'label': 'surprise', 'score': 0.27006053924560547},
#   {'label': 'neutral', 'score': 0.06813269853591919}],
#  [{'label': 'surprise', 'score': 0.41948410868644714},
#   {'label': 'joy', 'score': 0.23531347513198853},
#   {'label': 'neutral', 'score': 0.1927001178264618}],
#  [{'label': 'fear', 'score': 0.8644029498100281},
#   {'label': 'anger', 'score': 0.04959600418806076},
#   {'label': 'joy', 'score': 0.03338456526398659}],
#  [{'label': 'fear', 'score': 0.9834929704666138},
#   {'label': 'sadness', 'score': 0.005920263472944498},
#   {'label': 'anger', 'score': 0.0055014328099787235}],
#  [{'label': 'anger', 'score': 0.8830754160881042},
#   {'label': 'sadness', 'score': 0.08355215936899185},
#   {'label': 'fear', 'score': 0.02360517345368862}],
#  [{'label': 'joy', 'score': 0.4696871042251587},
#   {'label': 'neutral', 'score': 0.4496220350265503},
#   {'label': 'surprise', 'score': 0.05222773551940918}],
#  [{'label': 'neutral', 'score': 0.45476555824279785},
#   {'label': 'surprise', 'score': 0.36580559611320496},
#   {'label': 'sadness', 'score': 0.08559752255678177}],
#  [{'label': 'neutral', 'score': 0.41666272282600403},
#   {'label': 'surprise', 'score': 0.13855776190757751},
#   {'label': 'joy', 'score': 0.12911193072795868}],
#  [{'label': 'joy', 'score': 0.8324899077415466},
#   {'label': 'surprise', 'score': 0.110105000436306},
#   {'label': 'neutral', 'score': 0.040147121995687485}],
#  [{'label': 'anger', 'score': 0.4812818467617035},
#   {'label': 'surprise', 'score': 0.3018958568572998},
#   {'label': 'sadness', 'score': 0.1434701681137085}],
#  [{'label': 'neutral', 'score': 0.6052883863449097},
#   {'label': 'surprise', 'score': 0.18460486829280853},
#   {'label': 'fear', 'score': 0.15408176183700562}],
#  [{'label': 'fear', 'score': 0.983200192451477},
#   {'label': 'anger', 'score': 0.006137082818895578},
#   {'label': 'sadness', 'score': 0.005593182519078255}],
#  [{'label': 'joy', 'score': 0.9550269246101379},
#   {'label': 'surprise', 'score': 0.02726134844124317},
#   {'label': 'neutral', 'score': 0.011527097783982754}],
#  [{'label': 'joy', 'score': 0.7828311920166016},
#   {'label': 'surprise', 'score': 0.07569559663534164},
#   {'label': 'neutral', 'score': 0.06148933619260788}],
#  [{'label': 'fear', 'score': 0.8879401683807373},
#   {'label': 'anger', 'score': 0.04095439240336418},
#   {'label': 'joy', 'score': 0.028264619410037994}],
#  [{'label': 'fear', 'score': 0.9772053360939026},
#   {'label': 'anger', 'score': 0.009669904597103596},
#   {'label': 'sadness', 'score': 0.00804628524929285}],
#  [{'label': 'sadness', 'score': 0.9182605743408203},
#   {'label': 'fear', 'score': 0.047754280269145966},
#   {'label': 'anger', 'score': 0.021585669368505478}],
#  [{'label': 'fear', 'score': 0.7638220191001892},
#   {'label': 'anger', 'score': 0.1039644256234169},
#   {'label': 'joy', 'score': 0.04348013177514076}],
#  [{'label': 'neutral', 'score': 0.4825614094734192},
#   {'label': 'surprise', 'score': 0.25828665494918823},
#   {'label': 'joy', 'score': 0.2019253373146057}],
#  [{'label': 'fear', 'score': 0.9838154911994934},
#   {'label': 'anger', 'score': 0.005489451345056295},
#   {'label': 'sadness', 'score': 0.005294119939208031}],
#  [{'label': 'neutral', 'score': 0.8080243468284607},
#   {'label': 'surprise', 'score': 0.14631366729736328},
#   {'label': 'joy', 'score': 0.026720168069005013}],
#  [{'label': 'fear', 'score': 0.8772335648536682},
#   {'label': 'anger', 'score': 0.04430884122848511},
#   {'label': 'joy', 'score': 0.029953153803944588}],
#  [{'label': 'joy', 'score': 0.3448866009712219},
#   {'label': 'anger', 'score': 0.23689500987529755},
#   {'label': 'fear', 'score': 0.15601995587348938}],
#  [{'label': 'neutral', 'score': 0.8659483790397644},
#   {'label': 'surprise', 'score': 0.07346682250499725},
#   {'label': 'joy', 'score': 0.04587944597005844}],
#  [{'label': 'neutral', 'score': 0.6928707957267761},
#   {'label': 'joy', 'score': 0.15012110769748688},
#   {'label': 'surprise', 'score': 0.12475503981113434}],
#  [{'label': 'surprise', 'score': 0.7817239165306091},
#   {'label': 'neutral', 'score': 0.12812942266464233},
#   {'label': 'joy', 'score': 0.04692923650145531}],
#  [{'label': 'sadness', 'score': 0.5011546015739441},
#   {'label': 'surprise', 'score': 0.2940214276313782},
#   {'label': 'neutral', 'score': 0.14624972641468048}],
#  [{'label': 'anger', 'score': 0.5724780559539795},
#   {'label': 'sadness', 'score': 0.240234375},
#   {'label': 'surprise', 'score': 0.07617149502038956}],
#  [{'label': 'fear', 'score': 0.6590006947517395},
#   {'label': 'joy', 'score': 0.11640139669179916},
#   {'label': 'anger', 'score': 0.11579059064388275}],
#  [{'label': 'fear', 'score': 0.8998713493347168},
#   {'label': 'anger', 'score': 0.06533275544643402},
#   {'label': 'joy', 'score': 0.015543636865913868}],
#  [{'label': 'neutral', 'score': 0.6744804382324219},
#   {'label': 'joy', 'score': 0.24262122809886932},
#   {'label': 'surprise', 'score': 0.06589207798242569}],
#  [{'label': 'fear', 'score': 0.8777813911437988},
#   {'label': 'sadness', 'score': 0.07187438011169434},
#   {'label': 'anger', 'score': 0.03831561654806137}],
#  [{'label': 'surprise', 'score': 0.5507486462593079},
#   {'label': 'joy', 'score': 0.26660194993019104},
#   {'label': 'neutral', 'score': 0.10716621577739716}],
#  [{'label': 'anger', 'score': 0.7929095029830933},
#   {'label': 'sadness', 'score': 0.1539452224969864},
#   {'label': 'surprise', 'score': 0.016436846926808357}],
#  [{'label': 'fear', 'score': 0.8501668572425842},
#   {'label': 'anger', 'score': 0.053328145295381546},
#   {'label': 'joy', 'score': 0.04440799728035927}],
#  [{'label': 'joy', 'score': 0.9648345112800598},
#   {'label': 'surprise', 'score': 0.015912938863039017},
#   {'label': 'neutral', 'score': 0.013256989419460297}],
#  [{'label': 'sadness', 'score': 0.9028140902519226},
#   {'label': 'surprise', 'score': 0.04868433251976967},
#   {'label': 'neutral', 'score': 0.02521987073123455}],
#  [{'label': 'fear', 'score': 0.8321556448936462},
#   {'label': 'anger', 'score': 0.05801752954721451},
#   {'label': 'joy', 'score': 0.04492303356528282}],
#  [{'label': 'surprise', 'score': 0.7428281307220459},
#   {'label': 'sadness', 'score': 0.07570414245128632},
#   {'label': 'fear', 'score': 0.06787237524986267}],
#  [{'label': 'fear', 'score': 0.8455449342727661},
#   {'label': 'anger', 'score': 0.1333896666765213},
#   {'label': 'sadness', 'score': 0.014369836077094078}],
#  [{'label': 'surprise', 'score': 0.6324085593223572},
#   {'label': 'joy', 'score': 0.09772492200136185},
#   {'label': 'neutral', 'score': 0.08445025980472565}],
#  [{'label': 'joy', 'score': 0.4567336142063141},
#   {'label': 'surprise', 'score': 0.27946737408638},
#   {'label': 'neutral', 'score': 0.13394437730312347}],
#  [{'label': 'surprise', 'score': 0.43827351927757263},
#   {'label': 'neutral', 'score': 0.24141398072242737},
#   {'label': 'sadness', 'score': 0.17082005739212036}],
#  [{'label': 'anger', 'score': 0.9808963537216187},
#   {'label': 'fear', 'score': 0.005824268329888582},
#   {'label': 'sadness', 'score': 0.004721303004771471}],
#  [{'label': 'fear', 'score': 0.896146833896637},
#   {'label': 'anger', 'score': 0.06146992743015289},
#   {'label': 'joy', 'score': 0.020313095301389694}],
#  [{'label': 'neutral', 'score': 0.3610813319683075},
#   {'label': 'joy', 'score': 0.3522503077983856},
#   {'label': 'surprise', 'score': 0.24156446754932404}],
#  [{'label': 'fear', 'score': 0.6541614532470703},
#   {'label': 'anger', 'score': 0.3294302821159363},
#   {'label': 'joy', 'score': 0.006145494524389505}],
#  [{'label': 'neutral', 'score': 0.5609648823738098},
#   {'label': 'joy', 'score': 0.2937000095844269},
#   {'label': 'surprise', 'score': 0.10453000664710999}],
#  [{'label': 'fear', 'score': 0.35636448860168457},
#   {'label': 'anger', 'score': 0.3119383752346039},
#   {'label': 'surprise', 'score': 0.1237388625741005}],
#  [{'label': 'surprise', 'score': 0.4074840247631073},
#   {'label': 'neutral', 'score': 0.21539315581321716},
#   {'label': 'sadness', 'score': 0.14732536673545837}],
#  [{'label': 'neutral', 'score': 0.49756479263305664},
#   {'label': 'sadness', 'score': 0.30498379468917847},
#   {'label': 'surprise', 'score': 0.16958950459957123}],
#  [{'label': 'sadness', 'score': 0.32183897495269775},
#   {'label': 'joy', 'score': 0.26550617814064026},
#   {'label': 'surprise', 'score': 0.2207716852426529}],
#  [{'label': 'fear', 'score': 0.9261399507522583},
#   {'label': 'anger', 'score': 0.02214047871530056},
#   {'label': 'sadness', 'score': 0.018294792622327805}],
#  [{'label': 'surprise', 'score': 0.8828912973403931},
#   {'label': 'joy', 'score': 0.07288465648889542},
#   {'label': 'neutral', 'score': 0.031060706824064255}],
#  [{'label': 'surprise', 'score': 0.6447133421897888},
#   {'label': 'sadness', 'score': 0.16375389695167542},
#   {'label': 'anger', 'score': 0.09388292580842972}],
#  [{'label': 'joy', 'score': 0.42573148012161255},
#   {'label': 'neutral', 'score': 0.21955826878547668},
#   {'label': 'anger', 'score': 0.21871788799762726}],
#  [{'label': 'neutral', 'score': 0.6593201160430908},
#   {'label': 'surprise', 'score': 0.20162534713745117},
#   {'label': 'joy', 'score': 0.09519976377487183}],
#  [{'label': 'joy', 'score': 0.8136827945709229},
#   {'label': 'fear', 'score': 0.06921958178281784},
#   {'label': 'surprise', 'score': 0.06632822006940842}],
#  [{'label': 'fear', 'score': 0.8794690370559692},
#   {'label': 'anger', 'score': 0.04702045023441315},
#   {'label': 'joy', 'score': 0.0281812846660614}],
#  [{'label': 'joy', 'score': 0.6806760430335999},
#   {'label': 'neutral', 'score': 0.17496377229690552},
#   {'label': 'surprise', 'score': 0.09018094092607498}],
#  [{'label': 'neutral', 'score': 0.6703076362609863},
#   {'label': 'surprise', 'score': 0.18804731965065002},
#   {'label': 'sadness', 'score': 0.06974700838327408}],
#  [{'label': 'surprise', 'score': 0.4639786183834076},
#   {'label': 'neutral', 'score': 0.3448752462863922},
#   {'label': 'joy', 'score': 0.10998642444610596}],
#  [{'label': 'fear', 'score': 0.4261774718761444},
#   {'label': 'anger', 'score': 0.18396349251270294},
#   {'label': 'neutral', 'score': 0.13772821426391602}],
# ...
#   {'label': 'fear', 'score': 0.17454573512077332},
#   {'label': 'sadness', 'score': 0.1465940773487091}],
#  [{'label': 'neutral', 'score': 0.4912875294685364},
#   {'label': 'surprise', 'score': 0.3008275628089905},
#   {'label': 'joy', 'score': 0.11142180860042572}],
#  [{'label': 'sadness', 'score': 0.6086699366569519},
#   {'label': 'surprise', 'score': 0.12351585924625397},
#   {'label': 'joy', 'score': 0.12152331322431564}],
#  [{'label': 'surprise', 'score': 0.4412457346916199},
#   {'label': 'neutral', 'score': 0.32038772106170654},
#   {'label': 'joy', 'score': 0.19280970096588135}],
#  [{'label': 'fear', 'score': 0.7308160066604614},
#   {'label': 'anger', 'score': 0.16524450480937958},
#   {'label': 'neutral', 'score': 0.039434079080820084}],
#  [{'label': 'joy', 'score': 0.48746058344841003},
#   {'label': 'fear', 'score': 0.20810361206531525},
#   {'label': 'sadness', 'score': 0.10545754432678223}],
#  [{'label': 'surprise', 'score': 0.464480459690094},
#   {'label': 'fear', 'score': 0.33454594016075134},
#   {'label': 'neutral', 'score': 0.0961601510643959}],
#  [{'label': 'anger', 'score': 0.5326219201087952},
#   {'label': 'joy', 'score': 0.270763635635376},
#   {'label': 'disgust', 'score': 0.11757287383079529}],
#  [{'label': 'sadness', 'score': 0.7039660811424255},
#   {'label': 'surprise', 'score': 0.15160630643367767},
#   {'label': 'neutral', 'score': 0.04902777820825577}],
#  [{'label': 'surprise', 'score': 0.46334022283554077},
#   {'label': 'joy', 'score': 0.45062920451164246},
#   {'label': 'neutral', 'score': 0.06276826560497284}],
#  [{'label': 'neutral', 'score': 0.48365867137908936},
#   {'label': 'surprise', 'score': 0.29440179467201233},
#   {'label': 'joy', 'score': 0.15916907787322998}],
#  [{'label': 'surprise', 'score': 0.3810805082321167},
#   {'label': 'neutral', 'score': 0.251284122467041},
#   {'label': 'sadness', 'score': 0.23694784939289093}],
#  [{'label': 'surprise', 'score': 0.9144473671913147},
#   {'label': 'neutral', 'score': 0.03348010405898094},
#   {'label': 'anger', 'score': 0.025763755664229393}],
#  [{'label': 'joy', 'score': 0.4886207580566406},
#   {'label': 'fear', 'score': 0.16544415056705475},
#   {'label': 'sadness', 'score': 0.11992454528808594}],
#  [{'label': 'neutral', 'score': 0.6504437923431396},
#   {'label': 'joy', 'score': 0.2547450661659241},
#   {'label': 'surprise', 'score': 0.06113891676068306}],
#  [{'label': 'joy', 'score': 0.5112805962562561},
#   {'label': 'neutral', 'score': 0.31306907534599304},
#   {'label': 'surprise', 'score': 0.12399184703826904}],
#  [{'label': 'joy', 'score': 0.6230851411819458},
#   {'label': 'sadness', 'score': 0.09471217542886734},
#   {'label': 'fear', 'score': 0.08963027596473694}],
#  [{'label': 'anger', 'score': 0.9363656044006348},
#   {'label': 'fear', 'score': 0.03487417846918106},
#   {'label': 'sadness', 'score': 0.020172415301203728}],
#  [{'label': 'fear', 'score': 0.6717480421066284},
#   {'label': 'joy', 'score': 0.12174951285123825},
#   {'label': 'anger', 'score': 0.11166699975728989}],
#  [{'label': 'fear', 'score': 0.5938116908073425},
#   {'label': 'joy', 'score': 0.24233770370483398},
#   {'label': 'anger', 'score': 0.0816693976521492}],
#  [{'label': 'anger', 'score': 0.7975764870643616},
#   {'label': 'sadness', 'score': 0.08462755382061005},
#   {'label': 'disgust', 'score': 0.03916368633508682}],
#  [{'label': 'joy', 'score': 0.6923431158065796},
#   {'label': 'surprise', 'score': 0.18282219767570496},
#   {'label': 'neutral', 'score': 0.11080949753522873}],
#  [{'label': 'fear', 'score': 0.9878173470497131},
#   {'label': 'sadness', 'score': 0.006131300702691078},
#   {'label': 'anger', 'score': 0.0024848897010087967}],
#  [{'label': 'anger', 'score': 0.9463055729866028},
#   {'label': 'sadness', 'score': 0.02411493845283985},
#   {'label': 'fear', 'score': 0.01983715035021305}],
#  [{'label': 'neutral', 'score': 0.4915342926979065},
#   {'label': 'surprise', 'score': 0.18806742131710052},
#   {'label': 'fear', 'score': 0.15693750977516174}],
#  [{'label': 'anger', 'score': 0.5498461127281189},
#   {'label': 'sadness', 'score': 0.22416119277477264},
#   {'label': 'surprise', 'score': 0.1001277044415474}],
#  [{'label': 'anger', 'score': 0.5731799602508545},
#   {'label': 'surprise', 'score': 0.17351821064949036},
#   {'label': 'fear', 'score': 0.08481914550065994}],
#  [{'label': 'neutral', 'score': 0.6815500259399414},
#   {'label': 'joy', 'score': 0.15413081645965576},
#   {'label': 'surprise', 'score': 0.13608397543430328}],
#  [{'label': 'sadness', 'score': 0.7875162363052368},
#   {'label': 'joy', 'score': 0.12547723948955536},
#   {'label': 'anger', 'score': 0.043950606137514114}],
#  [{'label': 'fear', 'score': 0.9496650695800781},
#   {'label': 'anger', 'score': 0.01916319876909256},
#   {'label': 'joy', 'score': 0.012711945921182632}],
#  [{'label': 'anger', 'score': 0.6924453377723694},
#   {'label': 'fear', 'score': 0.18558940291404724},
#   {'label': 'joy', 'score': 0.07383621484041214}],
#  [{'label': 'anger', 'score': 0.987758457660675},
#   {'label': 'sadness', 'score': 0.0046523394994437695},
#   {'label': 'neutral', 'score': 0.002558612497523427}],
#  [{'label': 'joy', 'score': 0.46326372027397156},
#   {'label': 'fear', 'score': 0.26795127987861633},
#   {'label': 'sadness', 'score': 0.08890695124864578}],
#  [{'label': 'surprise', 'score': 0.4332514703273773},
#   {'label': 'sadness', 'score': 0.24733224511146545},
#   {'label': 'fear', 'score': 0.21446825563907623}],
#  [{'label': 'fear', 'score': 0.6377366781234741},
#   {'label': 'anger', 'score': 0.26946821808815},
#   {'label': 'surprise', 'score': 0.05018362030386925}],
#  [{'label': 'fear', 'score': 0.5159205794334412},
#   {'label': 'anger', 'score': 0.13988777995109558},
#   {'label': 'sadness', 'score': 0.10213200747966766}],
#  [{'label': 'joy', 'score': 0.5264910459518433},
#   {'label': 'fear', 'score': 0.14655938744544983},
#   {'label': 'sadness', 'score': 0.13843974471092224}],
#  [{'label': 'sadness', 'score': 0.6262410879135132},
#   {'label': 'surprise', 'score': 0.2859230041503906},
#   {'label': 'neutral', 'score': 0.05144587531685829}],
#  [{'label': 'joy', 'score': 0.8494985699653625},
#   {'label': 'neutral', 'score': 0.11998126655817032},
#   {'label': 'sadness', 'score': 0.014675323851406574}],
#  [{'label': 'joy', 'score': 0.668088436126709},
#   {'label': 'neutral', 'score': 0.14048321545124054},
#   {'label': 'surprise', 'score': 0.08635146915912628}],
#  [{'label': 'anger', 'score': 0.9027602672576904},
#   {'label': 'sadness', 'score': 0.05743749067187309},
#   {'label': 'surprise', 'score': 0.01646653190255165}],
#  [{'label': 'fear', 'score': 0.9530990719795227},
#   {'label': 'anger', 'score': 0.032431937754154205},
#   {'label': 'joy', 'score': 0.006268642842769623}],
#  [{'label': 'neutral', 'score': 0.9195340275764465},
#   {'label': 'surprise', 'score': 0.030038435012102127},
#   {'label': 'sadness', 'score': 0.01925402134656906}],
#  [{'label': 'sadness', 'score': 0.5441800355911255},
#   {'label': 'surprise', 'score': 0.3074246346950531},
#   {'label': 'anger', 'score': 0.06974773108959198}],
#  [{'label': 'joy', 'score': 0.6243913769721985},
#   {'label': 'sadness', 'score': 0.28117334842681885},
#   {'label': 'anger', 'score': 0.033353470265865326}],
#  [{'label': 'neutral', 'score': 0.40393584966659546},
#   {'label': 'surprise', 'score': 0.25947585701942444},
#   {'label': 'joy', 'score': 0.2515447437763214}],
#  [{'label': 'fear', 'score': 0.5749213695526123},
#   {'label': 'anger', 'score': 0.17482583224773407},
#   {'label': 'joy', 'score': 0.14483532309532166}],
#  [{'label': 'anger', 'score': 0.9469045996665955},
#   {'label': 'surprise', 'score': 0.017744338139891624},
#   {'label': 'fear', 'score': 0.01642836071550846}],
#  [{'label': 'joy', 'score': 0.4523666799068451},
#   {'label': 'sadness', 'score': 0.15949657559394836},
#   {'label': 'neutral', 'score': 0.12887150049209595}],
#  [{'label': 'sadness', 'score': 0.8781038522720337},
#   {'label': 'anger', 'score': 0.07803383469581604},
#   {'label': 'neutral', 'score': 0.013623125851154327}],
#  [{'label': 'anger', 'score': 0.8171300292015076},
#   {'label': 'fear', 'score': 0.06036959961056709},
#   {'label': 'sadness', 'score': 0.05732188746333122}],
#  [{'label': 'anger', 'score': 0.7503551244735718},
#   {'label': 'surprise', 'score': 0.10601358115673065},
#   {'label': 'disgust', 'score': 0.07393576949834824}],
#  [{'label': 'disgust', 'score': 0.5488942265510559},
#   {'label': 'neutral', 'score': 0.1460459679365158},
#   {'label': 'anger', 'score': 0.09316958487033844}],
#  [{'label': 'joy', 'score': 0.9046432971954346},
#   {'label': 'surprise', 'score': 0.04448854178190231},
#   {'label': 'neutral', 'score': 0.024892760440707207}],
#  [{'label': 'sadness', 'score': 0.910485029220581},
#   {'label': 'anger', 'score': 0.03566447272896767},
#   {'label': 'surprise', 'score': 0.026718448847532272}],
#  [{'label': 'neutral', 'score': 0.8914136290550232},
#   {'label': 'surprise', 'score': 0.030370283871889114},
#   {'label': 'joy', 'score': 0.024745896458625793}],
#  [{'label': 'neutral', 'score': 0.4764695167541504},
#   {'label': 'surprise', 'score': 0.3376733362674713},
#   {'label': 'sadness', 'score': 0.1550813466310501}],
#  [{'label': 'neutral', 'score': 0.5542200207710266},
#   {'label': 'joy', 'score': 0.28751516342163086},
#   {'label': 'surprise', 'score': 0.12228740006685257}],
#  [{'label': 'anger', 'score': 0.5708532333374023},
#   {'label': 'sadness', 'score': 0.3794446289539337},
#   {'label': 'fear', 'score': 0.02396063506603241}],
#  [{'label': 'neutral', 'score': 0.7101209759712219},
#   {'label': 'surprise', 'score': 0.2528603971004486},
#   {'label': 'anger', 'score': 0.01746894046664238}],
#  [{'label': 'fear', 'score': 0.7640992403030396},
#   {'label': 'anger', 'score': 0.09241329878568649},
#   {'label': 'sadness', 'score': 0.07615327090024948}],
#  [{'label': 'joy', 'score': 0.9259070754051208},
#   {'label': 'fear', 'score': 0.0328373946249485},
#   {'label': 'surprise', 'score': 0.01843484304845333}],
#  [{'label': 'anger', 'score': 0.4987625777721405},
#   {'label': 'sadness', 'score': 0.4229464828968048},
#   {'label': 'fear', 'score': 0.04158485680818558}],
#  [{'label': 'anger', 'score': 0.983834981918335},
#   {'label': 'fear', 'score': 0.008170018903911114},
#   {'label': 'sadness', 'score': 0.0035456616897135973}],
#  [{'label': 'surprise', 'score': 0.5996831655502319},
#   {'label': 'neutral', 'score': 0.3488066494464874},
#   {'label': 'joy', 'score': 0.03031609021127224}],
#  [{'label': 'surprise', 'score': 0.41308924555778503},
#   {'label': 'neutral', 'score': 0.4047051966190338},
#   {'label': 'joy', 'score': 0.16693787276744843}],
#  [{'label': 'anger', 'score': 0.6074002385139465},
#   {'label': 'surprise', 'score': 0.19216510653495789},
#   {'label': 'sadness', 'score': 0.09123912453651428}],
#  [{'label': 'neutral', 'score': 0.5924788117408752},
#   {'label': 'joy', 'score': 0.19613657891750336},
#   {'label': 'surprise', 'score': 0.18017880618572235}],
#  [{'label': 'surprise', 'score': 0.4772350788116455},
#   {'label': 'neutral', 'score': 0.2629978656768799},
#   {'label': 'sadness', 'score': 0.22255462408065796}],
#  [{'label': 'fear', 'score': 0.7613980174064636},
#   {'label': 'joy', 'score': 0.1173420175909996},
#   {'label': 'anger', 'score': 0.09390284866094589}],
#  [{'label': 'neutral', 'score': 0.7265335321426392},
#   {'label': 'sadness', 'score': 0.17354463040828705},
#   {'label': 'surprise', 'score': 0.05985550582408905}],
#  [{'label': 'fear', 'score': 0.6748319864273071},
#   {'label': 'sadness', 'score': 0.20129312574863434},
#   {'label': 'anger', 'score': 0.0661628395318985}],
#  [{'label': 'fear', 'score': 0.9071264863014221},
#   {'label': 'anger', 'score': 0.04464035481214523},
#   {'label': 'joy', 'score': 0.025210300460457802}],
#  [{'label': 'fear', 'score': 0.4682603180408478},
#   {'label': 'surprise', 'score': 0.4276522397994995},
#   {'label': 'anger', 'score': 0.04260971024632454}],
#  [{'label': 'surprise', 'score': 0.4079417884349823},
#   {'label': 'neutral', 'score': 0.2913878262042999},
#   {'label': 'sadness', 'score': 0.20407111942768097}],
#  [{'label': 'fear', 'score': 0.31086939573287964},
#   {'label': 'anger', 'score': 0.22999577224254608},
#   {'label': 'disgust', 'score': 0.2237624078989029}],
#  [{'label': 'neutral', 'score': 0.6180503368377686},
#   {'label': 'surprise', 'score': 0.25311747193336487},
#   {'label': 'joy', 'score': 0.06144503876566887}],
#  [{'label': 'surprise', 'score': 0.748322606086731},
#   {'label': 'neutral', 'score': 0.19926053285598755},
#   {'label': 'anger', 'score': 0.025979775935411453}],
#  [{'label': 'joy', 'score': 0.976502537727356},
#   {'label': 'surprise', 'score': 0.009843860752880573},
#   {'label': 'neutral', 'score': 0.008672893047332764}],
#  [{'label': 'fear', 'score': 0.337674617767334},
#   {'label': 'surprise', 'score': 0.3081047534942627},
#   {'label': 'neutral', 'score': 0.13089795410633087}],
#  [{'label': 'sadness', 'score': 0.9698430299758911},
#   {'label': 'surprise', 'score': 0.011944453231990337},
#   {'label': 'joy', 'score': 0.011792563833296299}],
#  [{'label': 'anger', 'score': 0.46016740798950195},
#   {'label': 'sadness', 'score': 0.2580280303955078},
#   {'label': 'fear', 'score': 0.18997988104820251}],
#  [{'label': 'anger', 'score': 0.33086085319519043},
#   {'label': 'joy', 'score': 0.18279187381267548},
#   {'label': 'surprise', 'score': 0.165605828166008}],
#  [{'label': 'fear', 'score': 0.9163317680358887},
#   {'label': 'anger', 'score': 0.043316200375556946},
#   {'label': 'joy', 'score': 0.018605461344122887}],
#  [{'label': 'joy', 'score': 0.48023155331611633},
#   {'label': 'anger', 'score': 0.25442221760749817},
#   {'label': 'surprise', 'score': 0.12342733889818192}],
#  [{'label': 'joy', 'score': 0.42717474699020386},
#   {'label': 'neutral', 'score': 0.41024282574653625},
#   {'label': 'sadness', 'score': 0.09937942773103714}],
#  [{'label': 'anger', 'score': 0.47088736295700073},
#   {'label': 'fear', 'score': 0.3376399278640747},
#   {'label': 'sadness', 'score': 0.06770702451467514}],
#  [{'label': 'neutral', 'score': 0.5822817087173462},
#   {'label': 'surprise', 'score': 0.20104511082172394},
#   {'label': 'sadness', 'score': 0.16145670413970947}],
#  [{'label': 'joy', 'score': 0.5132369995117188},
#   {'label': 'neutral', 'score': 0.28122931718826294},
#   {'label': 'surprise', 'score': 0.10164440423250198}],
#  [{'label': 'surprise', 'score': 0.9499116539955139},
#   {'label': 'neutral', 'score': 0.03366566076874733},
#   {'label': 'sadness', 'score': 0.0060744150541722775}],
#  [{'label': 'neutral', 'score': 0.4130968749523163},
#   {'label': 'surprise', 'score': 0.39755013585090637},
#   {'label': 'joy', 'score': 0.08638735860586166}],
#  [{'label': 'sadness', 'score': 0.4153233468532562},
#   {'label': 'surprise', 'score': 0.396843820810318},
#   {'label': 'neutral', 'score': 0.15885552763938904}],
#  [{'label': 'neutral', 'score': 0.6746373772621155},
#   {'label': 'surprise', 'score': 0.21348078548908234},
#   {'label': 'joy', 'score': 0.07173680514097214}],
#  [{'label': 'surprise', 'score': 0.36638930439949036},
#   {'label': 'neutral', 'score': 0.35028839111328125},
#   {'label': 'fear', 'score': 0.10049226135015488}],
#  [{'label': 'sadness', 'score': 0.934813916683197},
#   {'label': 'anger', 'score': 0.021279815584421158},
#   {'label': 'surprise', 'score': 0.016934268176555634}],
#  [{'label': 'anger', 'score': 0.769409716129303},
#   {'label': 'fear', 'score': 0.1411256194114685},
#   {'label': 'sadness', 'score': 0.032484814524650574}],
#  [{'label': 'joy', 'score': 0.6556133031845093},
#   {'label': 'neutral', 'score': 0.19809167087078094},
#   {'label': 'fear', 'score': 0.07630942016839981}],
#  [{'label': 'fear', 'score': 0.2991873025894165},
#   {'label': 'sadness', 'score': 0.2569003403186798},
#   {'label': 'anger', 'score': 0.18731196224689484}],
#  [{'label': 'surprise', 'score': 0.5279856324195862},
#   {'label': 'sadness', 'score': 0.21886536478996277},
#   {'label': 'joy', 'score': 0.13120438158512115}],
#  [{'label': 'anger', 'score': 0.965238094329834},
#   {'label': 'disgust', 'score': 0.01201718207448721},
#   {'label': 'surprise', 'score': 0.009274926967918873}],
#  [{'label': 'neutral', 'score': 0.45773544907569885},
#   {'label': 'sadness', 'score': 0.258491188287735},
#   {'label': 'surprise', 'score': 0.13459151983261108}],
#  ...]

# %%
df_emo_hartmann['emotion'] = pd.Series(emotions)

# %%
df_emo_hartmann.head()
# Out:
#                     id                                               text  \
# 0  1539397722595377152  @trashevrythng @hardevrythng @McDonalds and th...
# 1  1539397657571074049  @trashevrythng @hardevrythng @McDonalds respec...
# 2  1539397645625458688  @PeePosh2 @Scottschlittenh @sceley2011 @Joe_Ma...
# 3  1539397571013115904  @auauwra too bad im sending 8 mcdonalds large ...
# 4  1539397434715082754  @_idkjia Last time I went to McDonalds.  lol  ...
#
#                                              emotion
# 0  [{'label': 'joy', 'score': 0.365884006023407},...
# 1  [{'label': 'joy', 'score': 0.4457860291004181}...
# 2  [{'label': 'fear', 'score': 0.5146477818489075...
# 3  [{'label': 'sadness', 'score': 0.9574696421623...
# 4  [{'label': 'surprise', 'score': 0.665045678615...

# %%
df_emo_hartmann.tail()
# Out:
#                        id                                               text  \
# 5372  1539035600451514375  if belos comes back we should just give him a ...
# 5373  1539035573263863808  we were at mcdonalds and suddenly 4 school bus...
# 5374  1539035538300207104  IM SORRY I TOLD U TO DRINK MCDONALDS SPRITE ht...
# 5375  1539035499242864641  Tough times @McDonalds inflation is shrinking ...
# 5376  1539035475352211456  @McDonalds It's literally raw so I am not sure...
#
#                                                 emotion
# 5372  [{'label': 'neutral', 'score': 0.9272969365119...
# 5373  [{'label': 'surprise', 'score': 0.914400100708...
# 5374  [{'label': 'neutral', 'score': 0.5742588043212...
# 5375  [{'label': 'fear', 'score': 0.7552894949913025...
# 5376  [{'label': 'sadness', 'score': 0.5684058666229...

# %%
df_emo_hartmann['emotion']
# Out:
# 0       [{'label': 'joy', 'score': 0.365884006023407},...
# 1       [{'label': 'joy', 'score': 0.4457860291004181}...
# 2       [{'label': 'fear', 'score': 0.5146477818489075...
# 3       [{'label': 'sadness', 'score': 0.9574696421623...
# 4       [{'label': 'surprise', 'score': 0.665045678615...
#                               ...
# 5372    [{'label': 'neutral', 'score': 0.9272969365119...
# 5373    [{'label': 'surprise', 'score': 0.914400100708...
# 5374    [{'label': 'neutral', 'score': 0.5742588043212...
# 5375    [{'label': 'fear', 'score': 0.7552894949913025...
# 5376    [{'label': 'sadness', 'score': 0.5684058666229...
# Name: emotion, Length: 5377, dtype: object

# %%
 df_emo_hartmann['emotion'].map(lambda x: len(x)).value_counts()
# Out:
# 3    5377
# Name: emotion, dtype: int64

# %%
df_emo_hartmann['emotion'][0]
# Out:
# [{'label': 'joy', 'score': 0.365884006023407},
#  {'label': 'neutral', 'score': 0.2650728225708008},
#  {'label': 'fear', 'score': 0.1775878220796585}]

# %%
df_emo_hartmann['emotion'][0][0]['label']
# Out:
# 'joy'

# %%
df_emo_hartmann['emotion'][0][1]['label']
# Out:
# 'neutral'

# %%
df_emo_hartmann['emotion'][0][2]['label']
# Out:
# 'fear'

# %%
df_emo_hartmann['top1_emotion'] = df_emo_hartmann['emotion'].map(lambda x: x[0]['label'])
df_emo_hartmann['top2_emotion'] = df_emo_hartmann['emotion'].map(lambda x: x[1]['label'])
df_emo_hartmann['top3_emotion'] = df_emo_hartmann['emotion'].map(lambda x: x[2]['label'])

# %%
df_emo_hartmann
# Out:
#                        id                                               text  \
# 0     1539397722595377152  @trashevrythng @hardevrythng @McDonalds and th...
# 1     1539397657571074049  @trashevrythng @hardevrythng @McDonalds respec...
# 2     1539397645625458688  @PeePosh2 @Scottschlittenh @sceley2011 @Joe_Ma...
# 3     1539397571013115904  @auauwra too bad im sending 8 mcdonalds large ...
# 4     1539397434715082754  @_idkjia Last time I went to McDonalds.  lol  ...
# ...                   ...                                                ...
# 5372  1539035600451514375  if belos comes back we should just give him a ...
# 5373  1539035573263863808  we were at mcdonalds and suddenly 4 school bus...
# 5374  1539035538300207104  IM SORRY I TOLD U TO DRINK MCDONALDS SPRITE ht...
# 5375  1539035499242864641  Tough times @McDonalds inflation is shrinking ...
# 5376  1539035475352211456  @McDonalds It's literally raw so I am not sure...
#
#                                                 emotion top1_emotion  \
# 0     [{'label': 'joy', 'score': 0.365884006023407},...          joy
# 1     [{'label': 'joy', 'score': 0.4457860291004181}...          joy
# 2     [{'label': 'fear', 'score': 0.5146477818489075...         fear
# 3     [{'label': 'sadness', 'score': 0.9574696421623...      sadness
# 4     [{'label': 'surprise', 'score': 0.665045678615...     surprise
# ...                                                 ...          ...
# 5372  [{'label': 'neutral', 'score': 0.9272969365119...      neutral
# 5373  [{'label': 'surprise', 'score': 0.914400100708...     surprise
# 5374  [{'label': 'neutral', 'score': 0.5742588043212...      neutral
# 5375  [{'label': 'fear', 'score': 0.7552894949913025...         fear
# 5376  [{'label': 'sadness', 'score': 0.5684058666229...      sadness
#
#      top2_emotion top3_emotion
# 0         neutral         fear
# 1           anger      neutral
# 2           anger      sadness
# 3        surprise      neutral
# 4             joy      neutral
# ...           ...          ...
# 5372     surprise      sadness
# 5373         fear        anger
# 5374      sadness     surprise
# 5375      sadness        anger
# 5376     surprise      neutral
#
# [5377 rows x 6 columns]

# %%
df_emo_hartmann['top1_emotion'].value_counts()
# Out:
# neutral     1331
# fear         954
# surprise     861
# joy          782
# anger        734
# sadness      627
# disgust       88
# Name: top1_emotion, dtype: int64

# %%
df_emo_hartmann['top2_emotion'].value_counts()
# Out:
# surprise    1485
# neutral     1016
# anger        917
# joy          629
# sadness      611
# fear         596
# disgust      123
# Name: top2_emotion, dtype: int64

# %%
df_emo_hartmann['top3_emotion'].value_counts()
# Out:
# sadness     1132
# joy         1121
# surprise    1084
# neutral      880
# anger        630
# fear         402
# disgust      128
# Name: top3_emotion, dtype: int64
